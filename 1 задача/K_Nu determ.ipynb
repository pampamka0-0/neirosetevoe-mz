# %%
target_cols = 'K_Nu'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score,mean_absolute_percentage_error
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, callbacks
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import os

input_folder=f'C:/Users/1/projects/zadachi/1 задача/{target_cols} determ'
output_file=f'{target_cols} determ.csv'
columns = ['K_Nu', 'K_E', 'K_Rho', 'K_incl', 'F', 'K_lambda_r', 'A2', 'А2_surface',  'Nu_host medium', 'E', 'Rho', 'Vp', 'Vs', 'Z']
# Out:
# C:\Users\1\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
def merge_txt_files_to_dataset():
    all_data = []

    for filename in os.listdir(input_folder):
        if filename.endswith('.txt'):
            filepath = os.path.join(input_folder, filename)
            df = pd.read_csv(filepath, sep='\s+', header=None, names=columns)

            all_data.append(df)

    combined_df = pd.concat(all_data, ignore_index=True)
    combined_df.to_csv(output_file, index=False)
    print(f"Датасет сохранен в {output_file} (строк: {len(combined_df)})")

# Пример использования

merge_txt_files_to_dataset()
# Out:
# Датасет сохранен в K_Nu determ.csv (строк: 100100)

# %%
df = pd.read_csv(output_file)
df[:5]
# Out:
#    K_Nu  K_E  K_Rho  K_incl    F  K_lambda_r            A2    А2_surface  \
# 0   0.8    1      1       1  0.1   10.000000  5.331371e-13  5.331386e-13
# 1   0.8    1      1       1  0.2    5.000000  5.334869e-13  5.331507e-13
# 2   0.8    1      1       1  0.3    3.333333  5.366543e-13  5.363065e-13
# 3   0.8    1      1       1  0.4    2.500000  5.329471e-13  5.332102e-13
# 4   0.8    1      1       1  0.5    2.000000  5.331205e-13  5.332521e-13
#
#    Nu_host medium             E   Rho           Vp           Vs            Z
# 0            0.25  5.000000e+10  2700  4536.092116  2777.777778  2502.294446
# 1            0.25  5.000000e+10  2700  4536.092116  2777.777778  2502.294446
# 2            0.25  5.000000e+10  2700  4536.092116  2777.777778  2502.294446
# 3            0.25  5.000000e+10  2700  4536.092116  2777.777778  2502.294446
# 4            0.25  5.000000e+10  2700  4536.092116  2777.777778  2502.294446

# %%
pearson_corr = df[['A2', 'А2_surface', target_cols]].corr(method='pearson')
print("\nКорреляция Пирсона:")
print(pearson_corr.round(6))
# Out:
# Корреляция Пирсона:
#                   A2  А2_surface      K_Nu
# A2          1.000000    0.774975 -0.196032
# А2_surface  0.774975    1.000000  0.220893
# K_Nu       -0.196032    0.220893  1.000000

# %%
df['A2/A2_s'] = df['A2'] / df['А2_surface']
y = df[target_cols]
X = df[['A2/A2_s', 'F']]

# %%
scaler_X = StandardScaler()

X_scaled = scaler_X.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
model = Sequential([
    Dense(128, activation='relu', input_shape=(2,), name='hidden_layer_1'),
    Dropout(0.2),  # Добавляем Dropout для регуляризации
    Dense(64, activation='relu', name='hidden_layer_2'),
    Dropout(0.2),
    Dense(1, name='output_layer')
])
# Out:
# C:\Users\1\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='mse',
    metrics=['mae']
)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ hidden_layer_1 (Dense)          │ (None, 128)            │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden_layer_2 (Dense)          │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,705 (34.00 KB)
#  Trainable params: 8,705 (34.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Ранняя остановка для предотвращения переобучения
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True
)

# Обучение модели
history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 17s 6ms/step - loss: 0.0234 - mae: 0.1094 - val_loss: 0.0051 - val_mae: 0.0497
# Epoch 2/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.0077 - mae: 0.0676 - val_loss: 0.0039 - val_mae: 0.0403
# Epoch 3/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 22s 7ms/step - loss: 0.0048 - mae: 0.0509 - val_loss: 0.0034 - val_mae: 0.0381
# Epoch 4/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 22s 7ms/step - loss: 0.0038 - mae: 0.0436 - val_loss: 0.0029 - val_mae: 0.0328
# Epoch 5/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 18s 6ms/step - loss: 0.0035 - mae: 0.0406 - val_loss: 0.0028 - val_mae: 0.0338
# Epoch 6/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0032 - mae: 0.0389 - val_loss: 0.0029 - val_mae: 0.0349
# Epoch 7/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0031 - mae: 0.0382 - val_loss: 0.0026 - val_mae: 0.0301
# Epoch 8/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - loss: 0.0030 - mae: 0.0371 - val_loss: 0.0025 - val_mae: 0.0322
# Epoch 9/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0029 - mae: 0.0364 - val_loss: 0.0026 - val_mae: 0.0348
# Epoch 10/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - loss: 0.0029 - mae: 0.0362 - val_loss: 0.0024 - val_mae: 0.0273
# Epoch 11/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - loss: 0.0028 - mae: 0.0356 - val_loss: 0.0022 - val_mae: 0.0283
# Epoch 12/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0028 - mae: 0.0352 - val_loss: 0.0022 - val_mae: 0.0291
# Epoch 13/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0027 - mae: 0.0351 - val_loss: 0.0024 - val_mae: 0.0296
# Epoch 14/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0027 - mae: 0.0350 - val_loss: 0.0022 - val_mae: 0.0285
# Epoch 15/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - loss: 0.0027 - mae: 0.0348 - val_loss: 0.0025 - val_mae: 0.0319
# Epoch 16/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.0027 - mae: 0.0347 - val_loss: 0.0021 - val_mae: 0.0281
# Epoch 17/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0027 - mae: 0.0350 - val_loss: 0.0020 - val_mae: 0.0264
# Epoch 18/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0026 - mae: 0.0345 - val_loss: 0.0021 - val_mae: 0.0296
# Epoch 19/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - loss: 0.0026 - mae: 0.0344 - val_loss: 0.0024 - val_mae: 0.0303
# Epoch 20/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 18s 6ms/step - loss: 0.0026 - mae: 0.0344 - val_loss: 0.0021 - val_mae: 0.0262
# Epoch 21/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 19s 4ms/step - loss: 0.0026 - mae: 0.0342 - val_loss: 0.0024 - val_mae: 0.0315
# Epoch 22/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0026 - mae: 0.0341 - val_loss: 0.0021 - val_mae: 0.0282
# Epoch 23/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0026 - mae: 0.0339 - val_loss: 0.0023 - val_mae: 0.0283
# Epoch 24/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - loss: 0.0026 - mae: 0.0341 - val_loss: 0.0020 - val_mae: 0.0265
# Epoch 25/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0026 - mae: 0.0341 - val_loss: 0.0020 - val_mae: 0.0272
# Epoch 26/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0026 - mae: 0.0340 - val_loss: 0.0024 - val_mae: 0.0296
# Epoch 27/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0026 - mae: 0.0338 - val_loss: 0.0020 - val_mae: 0.0269
# Epoch 28/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0025 - mae: 0.0337 - val_loss: 0.0021 - val_mae: 0.0287
# Epoch 29/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0026 - mae: 0.0339 - val_loss: 0.0020 - val_mae: 0.0254
# Epoch 30/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 22s 7ms/step - loss: 0.0025 - mae: 0.0336 - val_loss: 0.0022 - val_mae: 0.0301
# Epoch 31/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - loss: 0.0025 - mae: 0.0335 - val_loss: 0.0019 - val_mae: 0.0280
# Epoch 32/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0025 - mae: 0.0335 - val_loss: 0.0020 - val_mae: 0.0272
# Epoch 33/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - loss: 0.0025 - mae: 0.0335 - val_loss: 0.0019 - val_mae: 0.0253
# Epoch 34/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0025 - mae: 0.0335 - val_loss: 0.0020 - val_mae: 0.0282
# Epoch 35/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.0025 - mae: 0.0334 - val_loss: 0.0019 - val_mae: 0.0268
# Epoch 36/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - loss: 0.0025 - mae: 0.0331 - val_loss: 0.0021 - val_mae: 0.0279
# Epoch 37/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 18s 5ms/step - loss: 0.0025 - mae: 0.0334 - val_loss: 0.0020 - val_mae: 0.0281
# Epoch 38/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0024 - mae: 0.0330 - val_loss: 0.0020 - val_mae: 0.0289
# Epoch 39/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.0024 - mae: 0.0330 - val_loss: 0.0018 - val_mae: 0.0260
# Epoch 40/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0024 - mae: 0.0329 - val_loss: 0.0018 - val_mae: 0.0274
# Epoch 41/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0024 - mae: 0.0329 - val_loss: 0.0018 - val_mae: 0.0245
# Epoch 42/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0025 - mae: 0.0330 - val_loss: 0.0019 - val_mae: 0.0267
# Epoch 43/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0025 - mae: 0.0333 - val_loss: 0.0019 - val_mae: 0.0275
# Epoch 44/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.0025 - mae: 0.0331 - val_loss: 0.0019 - val_mae: 0.0258
# Epoch 45/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0024 - mae: 0.0329 - val_loss: 0.0019 - val_mae: 0.0275
# Epoch 46/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0024 - mae: 0.0328 - val_loss: 0.0019 - val_mae: 0.0270
# Epoch 47/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0024 - mae: 0.0329 - val_loss: 0.0018 - val_mae: 0.0243
# Epoch 48/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0024 - mae: 0.0329 - val_loss: 0.0017 - val_mae: 0.0242
# Epoch 49/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0024 - mae: 0.0327 - val_loss: 0.0018 - val_mae: 0.0266
# Epoch 50/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0024 - mae: 0.0327 - val_loss: 0.0018 - val_mae: 0.0271
# Epoch 51/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - loss: 0.0024 - mae: 0.0324 - val_loss: 0.0017 - val_mae: 0.0235
# Epoch 52/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.0024 - mae: 0.0325 - val_loss: 0.0019 - val_mae: 0.0268
# Epoch 53/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0024 - mae: 0.0324 - val_loss: 0.0017 - val_mae: 0.0242
# Epoch 54/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0024 - mae: 0.0326 - val_loss: 0.0018 - val_mae: 0.0258
# Epoch 55/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0024 - mae: 0.0325 - val_loss: 0.0019 - val_mae: 0.0278
# Epoch 56/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.0024 - mae: 0.0322 - val_loss: 0.0018 - val_mae: 0.0267
# Epoch 57/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0024 - mae: 0.0323 - val_loss: 0.0020 - val_mae: 0.0273
# Epoch 58/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - loss: 0.0024 - mae: 0.0324 - val_loss: 0.0017 - val_mae: 0.0232
# Epoch 59/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0024 - mae: 0.0322 - val_loss: 0.0018 - val_mae: 0.0252
# Epoch 60/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0024 - mae: 0.0321 - val_loss: 0.0018 - val_mae: 0.0253
# Epoch 61/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0023 - mae: 0.0321 - val_loss: 0.0018 - val_mae: 0.0251
# Epoch 62/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0024 - mae: 0.0322 - val_loss: 0.0017 - val_mae: 0.0234
# Epoch 63/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0023 - mae: 0.0321 - val_loss: 0.0017 - val_mae: 0.0255
# Epoch 64/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0023 - mae: 0.0319 - val_loss: 0.0017 - val_mae: 0.0229
# Epoch 65/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0023 - mae: 0.0319 - val_loss: 0.0018 - val_mae: 0.0256
# Epoch 66/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0023 - mae: 0.0318 - val_loss: 0.0018 - val_mae: 0.0280
# Epoch 67/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0023 - mae: 0.0319 - val_loss: 0.0018 - val_mae: 0.0255
# Epoch 68/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0023 - mae: 0.0319 - val_loss: 0.0017 - val_mae: 0.0249
# Epoch 69/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0023 - mae: 0.0317 - val_loss: 0.0017 - val_mae: 0.0250
# Epoch 70/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0023 - mae: 0.0317 - val_loss: 0.0017 - val_mae: 0.0250
# Epoch 71/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0023 - mae: 0.0316 - val_loss: 0.0018 - val_mae: 0.0272
# Epoch 72/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0023 - mae: 0.0316 - val_loss: 0.0016 - val_mae: 0.0241
# Epoch 73/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0023 - mae: 0.0315 - val_loss: 0.0017 - val_mae: 0.0247
# Epoch 74/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0023 - mae: 0.0315 - val_loss: 0.0017 - val_mae: 0.0236
# Epoch 75/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.0022 - mae: 0.0312 - val_loss: 0.0017 - val_mae: 0.0250
# Epoch 76/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.0023 - mae: 0.0314 - val_loss: 0.0018 - val_mae: 0.0255
# Epoch 77/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0023 - mae: 0.0316 - val_loss: 0.0018 - val_mae: 0.0253
# Epoch 78/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0022 - mae: 0.0314 - val_loss: 0.0018 - val_mae: 0.0274
# Epoch 79/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0023 - mae: 0.0314 - val_loss: 0.0018 - val_mae: 0.0255
# Epoch 80/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0023 - mae: 0.0313 - val_loss: 0.0018 - val_mae: 0.0279
# Epoch 81/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0022 - mae: 0.0313 - val_loss: 0.0016 - val_mae: 0.0229
# Epoch 82/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0023 - mae: 0.0314 - val_loss: 0.0016 - val_mae: 0.0236
# Epoch 83/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0022 - mae: 0.0313 - val_loss: 0.0018 - val_mae: 0.0265
# Epoch 84/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0022 - mae: 0.0312 - val_loss: 0.0017 - val_mae: 0.0245
# Epoch 85/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0022 - mae: 0.0314 - val_loss: 0.0017 - val_mae: 0.0235
# Epoch 86/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0022 - mae: 0.0311 - val_loss: 0.0016 - val_mae: 0.0239
# Epoch 87/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0022 - mae: 0.0312 - val_loss: 0.0016 - val_mae: 0.0220
# Epoch 88/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.0022 - mae: 0.0312 - val_loss: 0.0016 - val_mae: 0.0233
# Epoch 89/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0022 - mae: 0.0312 - val_loss: 0.0018 - val_mae: 0.0265
# Epoch 90/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0022 - mae: 0.0311 - val_loss: 0.0018 - val_mae: 0.0259
# Epoch 91/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0022 - mae: 0.0313 - val_loss: 0.0015 - val_mae: 0.0215
# Epoch 92/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0022 - mae: 0.0312 - val_loss: 0.0017 - val_mae: 0.0263
# Epoch 93/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0022 - mae: 0.0310 - val_loss: 0.0017 - val_mae: 0.0248
# Epoch 94/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0022 - mae: 0.0314 - val_loss: 0.0017 - val_mae: 0.0235
# Epoch 95/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0022 - mae: 0.0312 - val_loss: 0.0017 - val_mae: 0.0238
# Epoch 96/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.0022 - mae: 0.0309 - val_loss: 0.0018 - val_mae: 0.0270
# Epoch 97/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0022 - mae: 0.0310 - val_loss: 0.0017 - val_mae: 0.0252
# Epoch 98/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 0.0022 - mae: 0.0311 - val_loss: 0.0017 - val_mae: 0.0269
# Epoch 99/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0022 - mae: 0.0311 - val_loss: 0.0017 - val_mae: 0.0249
# Epoch 100/100
# 2002/2002 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0022 - mae: 0.0311 - val_loss: 0.0017 - val_mae: 0.0248

# %%
y_pred= np.array(model.predict(X_test)).flatten()
y_test = np.array(y_test)
y_test, y_pred
# Out:
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# (array([0.9832, 0.9584, 0.9612, ..., 1.1068, 0.8892, 1.1848]),
#  array([0.9824485 , 0.9595135 , 1.0033227 , ..., 1.1132205 , 0.92231464,
#         1.1688287 ], dtype=float32))

# %%
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
relative_errors = np.abs((y_test - y_pred) / y_test) * 100
mean_relative_error = np.mean(relative_errors)
std_relative_error = np.std(relative_errors)

# %%
print("\n" + "="*50)
print("РЕЗУЛЬТАТЫ МОДЕЛИ")
print("="*50)
print(f"Mean Squared Error (MSE): {mse:.6f}")
print(f"Mean Absolute Error (MAE): {mae:.6f}")
print(f"Mean Absolute Per Error (MAPE): {mape:.6f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.6f}")
print(f"R² Score: {r2:.6f}")
# Out:
# ==================================================
# РЕЗУЛЬТАТЫ МОДЕЛИ
# ==================================================
# Mean Squared Error (MSE): 0.001456
# Mean Absolute Error (MAE): 0.020688
# Mean Absolute Per Error (MAPE): 0.021343
# Root Mean Squared Error (RMSE): 0.038154
# R² Score: 0.890758

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# 1. График обучения
axes[0, 0].plot(history.history['loss'], label='Train Loss')
axes[0, 0].plot(history.history['val_loss'], label='Validation Loss')
axes[0, 0].set_title('График обучения (Loss)')
axes[0, 0].set_xlabel('Эпохи')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].legend()
axes[0, 0].grid(True)

# 2. Сравнение предсказанных и реальных значений
axes[0, 1].scatter(y_test, y_pred, alpha=0.5)
axes[0, 1].plot([y_test.min(), y_test.max()], 
                [y_test.min(), y_test.max()], 'r--', lw=2)
axes[0, 1].set_title('Предсказанные vs Реальные значения')
axes[0, 1].set_xlabel(f'Реальные значения {target_cols}')
axes[0, 1].set_ylabel(f'Предсказанные значения {target_cols}')
axes[0, 1].grid(True)

# 3. Распределение ошибок
errors = y_test.flatten() - y_pred.flatten()
axes[1, 0].hist(errors, bins=50, edgecolor='black', alpha=0.7)
axes[1, 0].set_title('Распределение ошибок предсказания')
axes[1, 0].set_xlabel('Ошибка')
axes[1, 0].set_ylabel('Частота')
axes[1, 0].grid(True)

#
# 4. Распределение относительных ошибок
axes[1, 1].hist(relative_errors, bins=50, edgecolor='black', alpha=0.7, color='green')
axes[1, 1].axvline(mean_relative_error, color='red', linestyle='--', 
                   label=f'Средняя: {mean_relative_error:.2f}%')
axes[1, 1].axvline(mean_relative_error + std_relative_error, color='orange', 
                   linestyle=':', label=f'±1σ: {std_relative_error:.2f}%')
axes[1, 1].axvline(mean_relative_error - std_relative_error, color='orange', linestyle=':')
axes[1, 1].set_title('Распределение относительных ошибок')
axes[1, 1].set_xlabel('Относительная ошибка (%)')
axes[1, 1].set_ylabel('Частота')
axes[1, 1].legend()
axes[1, 1].grid(True)

plt.tight_layout()
plt.show()

# Дополнительная статистика
print("\n" + "="*50)
print("ДЕТАЛЬНАЯ СТАТИСТИКА")
print("="*50)
print(f"Минимальная относительная ошибка: {relative_errors.min():.2f}%")
print(f"Максимальная относительная ошибка: {relative_errors.max():.2f}%")
print(f"Медианная относительная ошибка: {np.median(relative_errors):.2f}%")
print(f"25-й перцентиль: {np.percentile(relative_errors, 25):.2f}%")
print(f"75-й перцентиль: {np.percentile(relative_errors, 75):.2f}%")


# Примеры предсказаний
print("\n" + "="*50)
print("ПРИМЕРЫ ПРЕДСКАЗАНИЙ (первые 10 тестовых образцов)")
print("="*50)
examples = pd.DataFrame({
    f'Реальный {target_cols}': y_test.flatten()[:10],
    f'Предсказанный {target_cols}': y_pred.flatten()[:10],
    'Абсолютная ошибка': np.abs(y_test.flatten()[:10] - y_pred.flatten()[:10]),
    'Относительная ошибка (%)': relative_errors.flatten()[:10]
})
print(examples.to_string(index=False))

# Сохранение модели
model.save(f'{target_cols}_prediction_model.h5')
print("\nМодель сохранена")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ==================================================
# ДЕТАЛЬНАЯ СТАТИСТИКА
# ==================================================
# Минимальная относительная ошибка: 0.00%
# Максимальная относительная ошибка: 25.98%
# Медианная относительная ошибка: 0.76%
# 25-й перцентиль: 0.31%
# 75-й перцентиль: 2.35%
#
# ==================================================
# ПРИМЕРЫ ПРЕДСКАЗАНИЙ (первые 10 тестовых образцов)
# ==================================================
#  Реальный K_Nu  Предсказанный K_Nu  Абсолютная ошибка  Относительная ошибка (%)
#         0.9832            0.982449           0.000751                  0.076432
#         0.9584            0.959513           0.001113                  0.116182
#         0.9612            1.003323           0.042123                  4.382306
#         0.8112            0.855257           0.044057                  5.431109
#         1.1624            1.168063           0.005663                  0.487186
#         0.8412            0.845621           0.004421                  0.525586
#         0.8228            0.842386           0.019586                  2.380351
#         1.0888            1.068780           0.020020                  1.838748
#         0.9808            0.936993           0.043807                  4.466407
#         0.8428            0.853710           0.010910                  1.294487
#
# Модель сохранена

# %%
accuracy_5_percent = np.mean(relative_errors < 5) * 100
print(f"Процент предсказаний с ошибкой < 5%: {accuracy_5_percent:.2f}%")
# Out:
# Процент предсказаний с ошибкой < 5%: 88.02%
