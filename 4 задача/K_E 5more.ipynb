# %%
target_cols = 'K_E'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score,mean_absolute_percentage_error
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, callbacks
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import os

input_folder=f'C:/Users/1/projects/zadachi/4 задача/{target_cols} 5more'
output_file=f'{target_cols} determ.csv'
columns = ['K_E', 'F', 'K_lambda_r', 'A2', 'А2_surface',  'Nu_host medium', 'E', 'Rho', 'Vp', 'Vs', 'Z']

# %%
def merge_txt_files_to_dataset():
    all_data = []

    for filename in os.listdir(input_folder):
        if filename.endswith('.txt'):
            filepath = os.path.join(input_folder, filename)
            df = pd.read_csv(filepath, sep='\s+', header=None, names=columns)

            all_data.append(df)

    combined_df = pd.concat(all_data, ignore_index=True)
    combined_df.to_csv(output_file, index=False)
    print(f"Датасет сохранен в {output_file} (строк: {len(combined_df)})")

# Пример использования

merge_txt_files_to_dataset()
# Out:
# Датасет сохранен в K_E determ.csv (строк: 495008)

# %%
df = pd.read_csv(output_file)
df[:5]
# Out:
#        K_E     F  K_lambda_r            A2    А2_surface  Nu_host medium  \
# 0  1.44646  0.10   10.000000  5.331264e-13  5.331300e-13            0.25
# 1  1.44646  0.12    8.333333  5.362985e-13  5.363488e-13            0.25
# 2  1.44646  0.14    7.142857  5.341398e-13  5.339686e-13            0.25
# 3  1.44646  0.16    6.250000  5.330598e-13  5.331756e-13            0.25
# 4  1.44646  0.18    5.555556  5.371449e-13  5.372998e-13            0.25
#
#               E   Rho           Vp           Vs            Z
# 0  5.000000e+10  2700  5669.528689  3273.303915  2502.294446
# 1  5.000000e+10  2700  5669.528689  3273.303915  2502.294446
# 2  5.000000e+10  2700  5669.528689  3273.303915  2502.294446
# 3  5.000000e+10  2700  5669.528689  3273.303915  2502.294446
# 4  5.000000e+10  2700  5669.528689  3273.303915  2502.294446

# %%
df['A2/A2_s'] = df['A2'] / df['А2_surface']
df = df[:99900]
y = df[target_cols]
X = df[['A2/A2_s', 'F']]
X
# Out:
#         A2/A2_s     F
# 0      0.999993  0.10
# 1      0.999906  0.12
# 2      1.000321  0.14
# 3      0.999783  0.16
# 4      0.999712  0.18
# ...         ...   ...
# 99895  1.060609  4.08
# 99896  1.060053  4.10
# 99897  1.059489  4.12
# 99898  1.058918  4.14
# 99899  1.058341  4.16
#
# [99900 rows x 2 columns]

# %%
pearson_corr = df[['A2/A2_s', 'F', target_cols]].corr(method='pearson')
print("\nКорреляция Пирсона:")
print(pearson_corr.round(6))
# Out:
# Корреляция Пирсона:
#           A2/A2_s         F      K_E
# A2/A2_s  1.000000 -0.054071 -0.12902
# F       -0.054071  1.000000  0.00275
# K_E     -0.129020  0.002750  1.00000

# %%
scaler_X = StandardScaler()

X_scaled = scaler_X.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
model = Sequential([
    Dense(128, activation='relu', input_shape=(2,), name='hidden_layer_1'),
    Dropout(0.2),  # Добавляем Dropout для регуляризации
    Dense(64, activation='relu', name='hidden_layer_2'),
    Dropout(0.2),
    Dense(1, name='output_layer')
])
# Out:
# C:\Users\1\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='mse',
    metrics=['mae']
)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ hidden_layer_1 (Dense)          │ (None, 128)            │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden_layer_2 (Dense)          │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,705 (34.00 KB)
#  Trainable params: 8,705 (34.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Ранняя остановка для предотвращения переобучения
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True
)

# Обучение модели
history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.1268 - mae: 0.2671 - val_loss: 0.0467 - val_mae: 0.1493
# Epoch 2/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0581 - mae: 0.1774 - val_loss: 0.0332 - val_mae: 0.1117
# Epoch 3/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 0.0438 - mae: 0.1482 - val_loss: 0.0284 - val_mae: 0.1036
# Epoch 4/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0372 - mae: 0.1335 - val_loss: 0.0251 - val_mae: 0.0890
# Epoch 5/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0336 - mae: 0.1247 - val_loss: 0.0232 - val_mae: 0.0850
# Epoch 6/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.0315 - mae: 0.1191 - val_loss: 0.0236 - val_mae: 0.0895
# Epoch 7/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.0302 - mae: 0.1160 - val_loss: 0.0238 - val_mae: 0.0857
# Epoch 8/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0298 - mae: 0.1144 - val_loss: 0.0216 - val_mae: 0.0815
# Epoch 9/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 0.0294 - mae: 0.1130 - val_loss: 0.0205 - val_mae: 0.0749
# Epoch 10/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0289 - mae: 0.1116 - val_loss: 0.0221 - val_mae: 0.0776
# Epoch 11/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.0279 - mae: 0.1091 - val_loss: 0.0232 - val_mae: 0.0856
# Epoch 12/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 0.0278 - mae: 0.1085 - val_loss: 0.0232 - val_mae: 0.0880
# Epoch 13/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0277 - mae: 0.1079 - val_loss: 0.0212 - val_mae: 0.0774
# Epoch 14/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.0274 - mae: 0.1066 - val_loss: 0.0204 - val_mae: 0.0745
# Epoch 15/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0271 - mae: 0.1059 - val_loss: 0.0202 - val_mae: 0.0747
# Epoch 16/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0268 - mae: 0.1050 - val_loss: 0.0195 - val_mae: 0.0704
# Epoch 17/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0263 - mae: 0.1041 - val_loss: 0.0196 - val_mae: 0.0707
# Epoch 18/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0268 - mae: 0.1043 - val_loss: 0.0198 - val_mae: 0.0731
# Epoch 19/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0259 - mae: 0.1030 - val_loss: 0.0187 - val_mae: 0.0698
# Epoch 20/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0256 - mae: 0.1021 - val_loss: 0.0195 - val_mae: 0.0732
# Epoch 21/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0255 - mae: 0.1016 - val_loss: 0.0225 - val_mae: 0.0874
# Epoch 22/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0253 - mae: 0.1016 - val_loss: 0.0195 - val_mae: 0.0703
# Epoch 23/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0252 - mae: 0.1008 - val_loss: 0.0193 - val_mae: 0.0695
# Epoch 24/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0249 - mae: 0.0999 - val_loss: 0.0187 - val_mae: 0.0710
# Epoch 25/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0248 - mae: 0.0997 - val_loss: 0.0171 - val_mae: 0.0665
# Epoch 26/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0289 - mae: 0.1020 - val_loss: 0.0190 - val_mae: 0.0732
# Epoch 27/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0251 - mae: 0.1001 - val_loss: 0.0203 - val_mae: 0.0790
# Epoch 28/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.0245 - mae: 0.0990 - val_loss: 0.0180 - val_mae: 0.0674
# Epoch 29/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0240 - mae: 0.0978 - val_loss: 0.0186 - val_mae: 0.0659
# Epoch 30/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0242 - mae: 0.0982 - val_loss: 0.0165 - val_mae: 0.0619
# Epoch 31/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0238 - mae: 0.0972 - val_loss: 0.0177 - val_mae: 0.0721
# Epoch 32/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.0246 - mae: 0.0986 - val_loss: 0.0180 - val_mae: 0.0735
# Epoch 33/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0237 - mae: 0.0968 - val_loss: 0.0167 - val_mae: 0.0641
# Epoch 34/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0237 - mae: 0.0968 - val_loss: 0.0191 - val_mae: 0.0737
# Epoch 35/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 0.0234 - mae: 0.0961 - val_loss: 0.0171 - val_mae: 0.0726
# Epoch 36/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0232 - mae: 0.0955 - val_loss: 0.0178 - val_mae: 0.0682
# Epoch 37/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.0232 - mae: 0.0958 - val_loss: 0.0173 - val_mae: 0.0675
# Epoch 38/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0232 - mae: 0.0956 - val_loss: 0.0171 - val_mae: 0.0624
# Epoch 39/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0233 - mae: 0.0955 - val_loss: 0.0166 - val_mae: 0.0698
# Epoch 40/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0234 - mae: 0.0955 - val_loss: 0.0171 - val_mae: 0.0647
# Epoch 41/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0230 - mae: 0.0950 - val_loss: 0.0164 - val_mae: 0.0613
# Epoch 42/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0227 - mae: 0.0939 - val_loss: 0.0169 - val_mae: 0.0647
# Epoch 43/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0228 - mae: 0.0941 - val_loss: 0.0186 - val_mae: 0.0756
# Epoch 44/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0229 - mae: 0.0948 - val_loss: 0.0153 - val_mae: 0.0612
# Epoch 45/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0226 - mae: 0.0939 - val_loss: 0.0160 - val_mae: 0.0691
# Epoch 46/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0227 - mae: 0.0940 - val_loss: 0.0184 - val_mae: 0.0766
# Epoch 47/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0225 - mae: 0.0937 - val_loss: 0.0153 - val_mae: 0.0601
# Epoch 48/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0224 - mae: 0.0936 - val_loss: 0.0166 - val_mae: 0.0652
# Epoch 49/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0225 - mae: 0.0935 - val_loss: 0.0151 - val_mae: 0.0581
# Epoch 50/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.0224 - mae: 0.0933 - val_loss: 0.0163 - val_mae: 0.0630
# Epoch 51/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0223 - mae: 0.0933 - val_loss: 0.0171 - val_mae: 0.0633
# Epoch 52/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0225 - mae: 0.0934 - val_loss: 0.0172 - val_mae: 0.0648
# Epoch 53/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0228 - mae: 0.0937 - val_loss: 0.0189 - val_mae: 0.0695
# Epoch 54/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0224 - mae: 0.0934 - val_loss: 0.0164 - val_mae: 0.0618
# Epoch 55/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0223 - mae: 0.0929 - val_loss: 0.0159 - val_mae: 0.0663
# Epoch 56/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0223 - mae: 0.0929 - val_loss: 0.0157 - val_mae: 0.0569
# Epoch 57/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0223 - mae: 0.0929 - val_loss: 0.0168 - val_mae: 0.0631
# Epoch 58/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0222 - mae: 0.0927 - val_loss: 0.0198 - val_mae: 0.0711
# Epoch 59/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0223 - mae: 0.0929 - val_loss: 0.0158 - val_mae: 0.0624
# Epoch 60/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0223 - mae: 0.0930 - val_loss: 0.0153 - val_mae: 0.0618
# Epoch 61/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0221 - mae: 0.0927 - val_loss: 0.0161 - val_mae: 0.0647
# Epoch 62/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0222 - mae: 0.0927 - val_loss: 0.0164 - val_mae: 0.0698
# Epoch 63/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0221 - mae: 0.0919 - val_loss: 0.0163 - val_mae: 0.0690
# Epoch 64/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0220 - mae: 0.0924 - val_loss: 0.0147 - val_mae: 0.0584
# Epoch 65/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0222 - mae: 0.0925 - val_loss: 0.0169 - val_mae: 0.0688
# Epoch 66/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.0221 - mae: 0.0922 - val_loss: 0.0157 - val_mae: 0.0645
# Epoch 67/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.0222 - mae: 0.0924 - val_loss: 0.0154 - val_mae: 0.0580
# Epoch 68/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0220 - mae: 0.0919 - val_loss: 0.0157 - val_mae: 0.0617
# Epoch 69/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0220 - mae: 0.0923 - val_loss: 0.0150 - val_mae: 0.0606
# Epoch 70/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0219 - mae: 0.0920 - val_loss: 0.0156 - val_mae: 0.0645
# Epoch 71/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0219 - mae: 0.0924 - val_loss: 0.0166 - val_mae: 0.0625
# Epoch 72/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0219 - mae: 0.0922 - val_loss: 0.0154 - val_mae: 0.0593
# Epoch 73/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0220 - mae: 0.0922 - val_loss: 0.0166 - val_mae: 0.0607
# Epoch 74/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0220 - mae: 0.0924 - val_loss: 0.0148 - val_mae: 0.0536
# Epoch 75/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0220 - mae: 0.0920 - val_loss: 0.0156 - val_mae: 0.0654
# Epoch 76/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0219 - mae: 0.0919 - val_loss: 0.0157 - val_mae: 0.0619
# Epoch 77/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0219 - mae: 0.0918 - val_loss: 0.0150 - val_mae: 0.0605
# Epoch 78/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0223 - mae: 0.0921 - val_loss: 0.0153 - val_mae: 0.0598
# Epoch 79/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0217 - mae: 0.0915 - val_loss: 0.0145 - val_mae: 0.0564
# Epoch 80/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0218 - mae: 0.0917 - val_loss: 0.0156 - val_mae: 0.0619
# Epoch 81/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0218 - mae: 0.0916 - val_loss: 0.0159 - val_mae: 0.0623
# Epoch 82/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0220 - mae: 0.0920 - val_loss: 0.0148 - val_mae: 0.0569
# Epoch 83/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.0218 - mae: 0.0916 - val_loss: 0.0152 - val_mae: 0.0607
# Epoch 84/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.0219 - mae: 0.0921 - val_loss: 0.0152 - val_mae: 0.0613
# Epoch 85/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0219 - mae: 0.0915 - val_loss: 0.0145 - val_mae: 0.0546
# Epoch 86/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0217 - mae: 0.0913 - val_loss: 0.0151 - val_mae: 0.0585
# Epoch 87/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 0.0218 - mae: 0.0919 - val_loss: 0.0161 - val_mae: 0.0648
# Epoch 88/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0218 - mae: 0.0915 - val_loss: 0.0148 - val_mae: 0.0584
# Epoch 89/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0218 - mae: 0.0914 - val_loss: 0.0169 - val_mae: 0.0708
# Epoch 90/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.0218 - mae: 0.0916 - val_loss: 0.0159 - val_mae: 0.0595
# Epoch 91/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0218 - mae: 0.0919 - val_loss: 0.0155 - val_mae: 0.0587
# Epoch 92/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0218 - mae: 0.0915 - val_loss: 0.0155 - val_mae: 0.0595
# Epoch 93/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - loss: 0.0223 - mae: 0.0924 - val_loss: 0.0151 - val_mae: 0.0601
# Epoch 94/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 22s 8ms/step - loss: 0.0217 - mae: 0.0913 - val_loss: 0.0166 - val_mae: 0.0641
# Epoch 95/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - loss: 0.0222 - mae: 0.0921 - val_loss: 0.0151 - val_mae: 0.0613
# Epoch 96/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 0.0216 - mae: 0.0916 - val_loss: 0.0159 - val_mae: 0.0633
# Epoch 97/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 29s 14ms/step - loss: 0.0220 - mae: 0.0918 - val_loss: 0.0151 - val_mae: 0.0559
# Epoch 98/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 27s 13ms/step - loss: 0.0216 - mae: 0.0910 - val_loss: 0.0150 - val_mae: 0.0593
# Epoch 99/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 24s 12ms/step - loss: 0.0218 - mae: 0.0915 - val_loss: 0.0169 - val_mae: 0.0615
# Epoch 100/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 34s 8ms/step - loss: 0.0217 - mae: 0.0912 - val_loss: 0.0149 - val_mae: 0.0576

# %%
y_pred= np.array(model.predict(X_test)).flatten()
y_test = np.array(y_test)
y_test, y_pred
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step
# (array([1.40582 , 0.57189 , 1.39368 , ..., 0.99351 , 1.79283 , 0.848742]),
#  array([1.4860376 , 0.6066973 , 1.3063517 , ..., 1.3126452 , 1.8160604 ,
#         0.84838814], dtype=float32))

# %%
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
relative_errors = np.abs((y_test - y_pred) / y_test) * 100
mean_relative_error = np.mean(relative_errors)
std_relative_error = np.std(relative_errors)

# %%
print("\n" + "="*50)
print("РЕЗУЛЬТАТЫ МОДЕЛИ")
print("="*50)
print(f"Mean Squared Error (MSE): {mse:.6f}")
print(f"Mean Absolute Error (MAE): {mae:.6f}")
print(f"Mean Absolute Per Error (MAPE): {mape:.6f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.6f}")
print(f"R² Score: {r2:.6f}")
# Out:
# ==================================================
# РЕЗУЛЬТАТЫ МОДЕЛИ
# ==================================================
# Mean Squared Error (MSE): 0.014198
# Mean Absolute Error (MAE): 0.054246
# Mean Absolute Per Error (MAPE): 0.050370
# Root Mean Squared Error (RMSE): 0.119154
# R² Score: 0.916409

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# 1. График обучения
axes[0, 0].plot(history.history['loss'], label='Train Loss')
axes[0, 0].plot(history.history['val_loss'], label='Validation Loss')
axes[0, 0].set_title('График обучения (Loss)')
axes[0, 0].set_xlabel('Эпохи')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].legend()
axes[0, 0].grid(True)

# 2. Сравнение предсказанных и реальных значений
axes[0, 1].scatter(y_test, y_pred, alpha=0.5)
axes[0, 1].plot([y_test.min(), y_test.max()], 
                [y_test.min(), y_test.max()], 'r--', lw=2)
axes[0, 1].set_title('Предсказанные vs Реальные значения')
axes[0, 1].set_xlabel(f'Реальные значения {target_cols}')
axes[0, 1].set_ylabel(f'Предсказанные значения {target_cols}')
axes[0, 1].grid(True)

# 3. Распределение ошибок
errors = y_test.flatten() - y_pred.flatten()
axes[1, 0].hist(errors, bins=50, edgecolor='black', alpha=0.7)
axes[1, 0].set_title('Распределение ошибок предсказания')
axes[1, 0].set_xlabel('Ошибка')
axes[1, 0].set_ylabel('Частота')
axes[1, 0].grid(True)

#
# 4. Распределение относительных ошибок
axes[1, 1].hist(relative_errors, bins=50, edgecolor='black', alpha=0.7, color='green')
axes[1, 1].axvline(mean_relative_error, color='red', linestyle='--', 
                   label=f'Средняя: {mean_relative_error:.2f}%')
axes[1, 1].axvline(mean_relative_error + std_relative_error, color='orange', 
                   linestyle=':', label=f'±1σ: {std_relative_error:.2f}%')
axes[1, 1].axvline(mean_relative_error - std_relative_error, color='orange', linestyle=':')
axes[1, 1].set_title('Распределение относительных ошибок')
axes[1, 1].set_xlabel('Относительная ошибка (%)')
axes[1, 1].set_ylabel('Частота')
axes[1, 1].legend()
axes[1, 1].grid(True)

plt.tight_layout()
plt.show()

# Дополнительная статистика
print("\n" + "="*50)
print("ДЕТАЛЬНАЯ СТАТИСТИКА")
print("="*50)
print(f"Минимальная относительная ошибка: {relative_errors.min():.2f}%")
print(f"Максимальная относительная ошибка: {relative_errors.max():.2f}%")
print(f"Медианная относительная ошибка: {np.median(relative_errors):.2f}%")
print(f"25-й перцентиль: {np.percentile(relative_errors, 25):.2f}%")
print(f"75-й перцентиль: {np.percentile(relative_errors, 75):.2f}%")


# Примеры предсказаний
print("\n" + "="*50)
print("ПРИМЕРЫ ПРЕДСКАЗАНИЙ (первые 10 тестовых образцов)")
print("="*50)
examples = pd.DataFrame({
    f'Реальный {target_cols}': y_test.flatten()[:10],
    f'Предсказанный {target_cols}': y_pred.flatten()[:10],
    'Абсолютная ошибка': np.abs(y_test.flatten()[:10] - y_pred.flatten()[:10]),
    'Относительная ошибка (%)': relative_errors.flatten()[:10]
})
print(examples.to_string(index=False))

# Сохранение модели
model.save(f'{target_cols}_prediction_model.h5')
print("\nМодель сохранена")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ==================================================
# ДЕТАЛЬНАЯ СТАТИСТИКА
# ==================================================
# Минимальная относительная ошибка: 0.00%
# Максимальная относительная ошибка: 201.46%
# Медианная относительная ошибка: 1.50%
# 25-й перцентиль: 0.79%
# 75-й перцентиль: 3.71%
#
# ==================================================
# ПРИМЕРЫ ПРЕДСКАЗАНИЙ (первые 10 тестовых образцов)
# ==================================================
#  Реальный K_E  Предсказанный K_E  Абсолютная ошибка  Относительная ошибка (%)
#       1.40582           1.486038           0.080218                  5.706108
#       0.57189           0.606697           0.034807                  6.086366
#       1.39368           1.306352           0.087328                  6.266025
#       1.66317           1.730605           0.067435                  4.054628
#       1.53846           1.399957           0.138503                  9.002716
#       1.50994           1.518775           0.008835                  0.585153
#       1.77069           1.771786           0.001096                  0.061895
#       1.82190           1.576717           0.245183                 13.457530
#       1.10607           1.123104           0.017034                  1.540056
#       1.08076           1.091907           0.011147                  1.031417
#
# Модель сохранена

# %%
accuracy_5_percent = np.mean(relative_errors < 5) * 100
print(f"Процент предсказаний с ошибкой < 5%: {accuracy_5_percent:.2f}%")
# Out:
# Процент предсказаний с ошибкой < 5%: 79.37%
