# %%
target_cols = 'K_Rho'

output_file=f'{target_cols} determ.csv'
columns = ['K_Nu', 'K_E', 'K_Rho', 'K_incl', 'F', 'K_lambda_r', 'A2', 'А2_surface',  'Nu_host medium', 'E', 'Rho', 'Vp', 'Vs', 'Z']
p1, p2, p3 = 0.0, 10.1, 0.5

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, callbacks
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, Input
from tensorflow.keras.optimizers import Adam
# Out:
# C:\Users\1\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
import pandas as pd
df = pd.read_csv(output_file)
df
# Out:
#         K_Nu     K_E  K_Rho  K_incl_top_position_y     F  K_lambda_r  \
# 0          1  0.5000      1                      1   0.1   10.000000
# 1          1  0.5000      1                      1   0.2    5.000000
# 2          1  0.5000      1                      1   0.3    3.333333
# 3          1  0.5000      1                      1   0.4    2.500000
# 4          1  0.5000      1                      1   0.5    2.000000
# ...      ...     ...    ...                    ...   ...         ...
# 100095     1  0.5135      1                      1   9.6    0.104167
# 100096     1  0.5135      1                      1   9.7    0.103093
# 100097     1  0.5135      1                      1   9.8    0.102041
# 100098     1  0.5135      1                      1   9.9    0.101010
# 100099     1  0.5135      1                      1  10.0    0.100000
#
#                   A2    А2_surface  Nu_host medium             E   Rho  \
# 0       5.331410e-13  5.331447e-13            0.25  5.000000e+10  2700
# 1       5.334885e-13  5.331474e-13            0.25  5.000000e+10  2700
# 2       5.367156e-13  5.363296e-13            0.25  5.000000e+10  2700
# 3       5.324516e-13  5.329968e-13            0.25  5.000000e+10  2700
# 4       5.332178e-13  5.322721e-13            0.25  5.000000e+10  2700
# ...              ...           ...             ...           ...   ...
# 100095  5.526740e-13  5.640118e-13            0.25  5.000000e+10  2700
# 100096  5.517025e-13  5.630990e-13            0.25  5.000000e+10  2700
# 100097  5.508005e-13  5.622432e-13            0.25  5.000000e+10  2700
# 100098  5.499630e-13  5.614406e-13            0.25  5.000000e+10  2700
# 100099  5.492409e-13  5.606671e-13            0.25  5.000000e+10  2700
#
#                  Vp           Vs            Z
# 0       3333.333333  1924.500897  2502.294446
# 1       3333.333333  1924.500897  2502.294446
# 2       3333.333333  1924.500897  2502.294446
# 3       3333.333333  1924.500897  2502.294446
# 4       3333.333333  1924.500897  2502.294446
# ...             ...          ...          ...
# 100095  3378.033616  1950.308618  2502.294446
# 100096  3378.033616  1950.308618  2502.294446
# 100097  3378.033616  1950.308618  2502.294446
# 100098  3378.033616  1950.308618  2502.294446
# 100099  3378.033616  1950.308618  2502.294446
#
# [100100 rows x 14 columns]

# %%
delete_values = np.arange(p1, p2, p3).round(1).tolist()
df = df[df['F'].round(1).isin(delete_values)]

# %%
df['A2/A2_s'] = df['A2'] / df['А2_surface']
y = df[target_cols]
X = df[['A2/A2_s', 'F']]
X[:5]
# Out:
# C:\Users\1\AppData\Local\Temp\ipykernel_15364\3331272413.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['A2/A2_s'] = df['A2'] / df['А2_surface']
#      A2/A2_s    F
# 4   1.001777  0.5
# 9   1.064934  1.0
# 14  0.833787  1.5
# 19  0.761069  2.0
# 24  0.878752  2.5

# %%
scaler_X = StandardScaler()

X_scaled = scaler_X.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
model = Sequential([
    Dense(128, activation='relu', input_shape=(2,), name='hidden_layer_1'),
    Dropout(0.2),  # Добавляем Dropout для регуляризации
    Dense(64, activation='relu', name='hidden_layer_2'),
    Dropout(0.2),
    Dense(1, name='output_layer')
])
# Out:
# C:\Users\1\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='mse',
    metrics=['mae']
)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ hidden_layer_1 (Dense)          │ (None, 128)            │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden_layer_2 (Dense)          │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,705 (34.00 KB)
#  Trainable params: 8,705 (34.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Ранняя остановка для предотвращения переобучения
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True
)

# Обучение модели
history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2631 - mae: 0.4014 - val_loss: 0.1115 - val_mae: 0.2685
# Epoch 2/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1166 - mae: 0.2684 - val_loss: 0.0735 - val_mae: 0.2009
# Epoch 3/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0932 - mae: 0.2348 - val_loss: 0.0598 - val_mae: 0.1703
# Epoch 4/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0830 - mae: 0.2170 - val_loss: 0.0535 - val_mae: 0.1557
# Epoch 5/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0765 - mae: 0.2064 - val_loss: 0.0498 - val_mae: 0.1447
# Epoch 6/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0717 - mae: 0.1987 - val_loss: 0.0483 - val_mae: 0.1455
# Epoch 7/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0683 - mae: 0.1931 - val_loss: 0.0434 - val_mae: 0.1339
# Epoch 8/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0630 - mae: 0.1843 - val_loss: 0.0430 - val_mae: 0.1308
# Epoch 9/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0595 - mae: 0.1772 - val_loss: 0.0393 - val_mae: 0.1216
# Epoch 10/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0570 - mae: 0.1722 - val_loss: 0.0396 - val_mae: 0.1237
# Epoch 11/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0543 - mae: 0.1674 - val_loss: 0.0363 - val_mae: 0.1148
# Epoch 12/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0523 - mae: 0.1630 - val_loss: 0.0395 - val_mae: 0.1202
# Epoch 13/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0505 - mae: 0.1593 - val_loss: 0.0358 - val_mae: 0.1149
# Epoch 14/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0489 - mae: 0.1564 - val_loss: 0.0361 - val_mae: 0.1157
# Epoch 15/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0484 - mae: 0.1559 - val_loss: 0.0345 - val_mae: 0.1102
# Epoch 16/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0477 - mae: 0.1536 - val_loss: 0.0349 - val_mae: 0.1112
# Epoch 17/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0463 - mae: 0.1505 - val_loss: 0.0363 - val_mae: 0.1167
# Epoch 18/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0461 - mae: 0.1499 - val_loss: 0.0337 - val_mae: 0.1110
# Epoch 19/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0452 - mae: 0.1485 - val_loss: 0.0355 - val_mae: 0.1167
# Epoch 20/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0443 - mae: 0.1455 - val_loss: 0.0331 - val_mae: 0.1094
# Epoch 21/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0445 - mae: 0.1470 - val_loss: 0.0332 - val_mae: 0.1085
# Epoch 22/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0432 - mae: 0.1446 - val_loss: 0.0315 - val_mae: 0.1012
# Epoch 23/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0429 - mae: 0.1413 - val_loss: 0.0337 - val_mae: 0.1086
# Epoch 24/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0432 - mae: 0.1437 - val_loss: 0.0322 - val_mae: 0.1048
# Epoch 25/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0431 - mae: 0.1431 - val_loss: 0.0323 - val_mae: 0.1061
# Epoch 26/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0413 - mae: 0.1402 - val_loss: 0.0320 - val_mae: 0.1039
# Epoch 27/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0415 - mae: 0.1397 - val_loss: 0.0307 - val_mae: 0.1005
# Epoch 28/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0413 - mae: 0.1395 - val_loss: 0.0317 - val_mae: 0.1053
# Epoch 29/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0401 - mae: 0.1370 - val_loss: 0.0288 - val_mae: 0.0944
# Epoch 30/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0405 - mae: 0.1362 - val_loss: 0.0285 - val_mae: 0.0953
# Epoch 31/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0398 - mae: 0.1363 - val_loss: 0.0294 - val_mae: 0.1018
# Epoch 32/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0389 - mae: 0.1349 - val_loss: 0.0289 - val_mae: 0.1018
# Epoch 33/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0383 - mae: 0.1330 - val_loss: 0.0288 - val_mae: 0.1039
# Epoch 34/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0373 - mae: 0.1316 - val_loss: 0.0276 - val_mae: 0.0976
# Epoch 35/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0379 - mae: 0.1326 - val_loss: 0.0256 - val_mae: 0.0909
# Epoch 36/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0363 - mae: 0.1288 - val_loss: 0.0262 - val_mae: 0.0938
# Epoch 37/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0352 - mae: 0.1286 - val_loss: 0.0266 - val_mae: 0.0930
# Epoch 38/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0360 - mae: 0.1275 - val_loss: 0.0259 - val_mae: 0.0922
# Epoch 39/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0353 - mae: 0.1269 - val_loss: 0.0267 - val_mae: 0.0961
# Epoch 40/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0354 - mae: 0.1262 - val_loss: 0.0252 - val_mae: 0.0902
# Epoch 41/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0342 - mae: 0.1240 - val_loss: 0.0249 - val_mae: 0.0902
# Epoch 42/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0348 - mae: 0.1248 - val_loss: 0.0235 - val_mae: 0.0856
# Epoch 43/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0342 - mae: 0.1240 - val_loss: 0.0239 - val_mae: 0.0896
# Epoch 44/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0337 - mae: 0.1237 - val_loss: 0.0242 - val_mae: 0.0930
# Epoch 45/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0332 - mae: 0.1214 - val_loss: 0.0228 - val_mae: 0.0834
# Epoch 46/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0336 - mae: 0.1229 - val_loss: 0.0241 - val_mae: 0.0844
# Epoch 47/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0331 - mae: 0.1211 - val_loss: 0.0266 - val_mae: 0.0928
# Epoch 48/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0326 - mae: 0.1207 - val_loss: 0.0253 - val_mae: 0.0910
# Epoch 49/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0334 - mae: 0.1220 - val_loss: 0.0235 - val_mae: 0.0850
# Epoch 50/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0326 - mae: 0.1212 - val_loss: 0.0242 - val_mae: 0.0893
# Epoch 51/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0329 - mae: 0.1206 - val_loss: 0.0226 - val_mae: 0.0854
# Epoch 52/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0328 - mae: 0.1199 - val_loss: 0.0218 - val_mae: 0.0767
# Epoch 53/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0318 - mae: 0.1183 - val_loss: 0.0222 - val_mae: 0.0842
# Epoch 54/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0324 - mae: 0.1194 - val_loss: 0.0212 - val_mae: 0.0761
# Epoch 55/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0314 - mae: 0.1178 - val_loss: 0.0219 - val_mae: 0.0821
# Epoch 56/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0310 - mae: 0.1166 - val_loss: 0.0235 - val_mae: 0.0899
# Epoch 57/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0309 - mae: 0.1173 - val_loss: 0.0236 - val_mae: 0.0885
# Epoch 58/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0313 - mae: 0.1165 - val_loss: 0.0231 - val_mae: 0.0849
# Epoch 59/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0315 - mae: 0.1173 - val_loss: 0.0213 - val_mae: 0.0768
# Epoch 60/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0305 - mae: 0.1159 - val_loss: 0.0206 - val_mae: 0.0779
# Epoch 61/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0309 - mae: 0.1171 - val_loss: 0.0212 - val_mae: 0.0776
# Epoch 62/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0305 - mae: 0.1162 - val_loss: 0.0208 - val_mae: 0.0785
# Epoch 63/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0304 - mae: 0.1158 - val_loss: 0.0206 - val_mae: 0.0784
# Epoch 64/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0288 - mae: 0.1125 - val_loss: 0.0216 - val_mae: 0.0782
# Epoch 65/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0305 - mae: 0.1160 - val_loss: 0.0246 - val_mae: 0.0966
# Epoch 66/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0300 - mae: 0.1137 - val_loss: 0.0207 - val_mae: 0.0777
# Epoch 67/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0304 - mae: 0.1151 - val_loss: 0.0210 - val_mae: 0.0792
# Epoch 68/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0301 - mae: 0.1145 - val_loss: 0.0211 - val_mae: 0.0764
# Epoch 69/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0294 - mae: 0.1136 - val_loss: 0.0202 - val_mae: 0.0743
# Epoch 70/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0287 - mae: 0.1119 - val_loss: 0.0214 - val_mae: 0.0795
# Epoch 71/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0294 - mae: 0.1135 - val_loss: 0.0214 - val_mae: 0.0801
# Epoch 72/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0293 - mae: 0.1129 - val_loss: 0.0214 - val_mae: 0.0766
# Epoch 73/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0298 - mae: 0.1140 - val_loss: 0.0221 - val_mae: 0.0819
# Epoch 74/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0284 - mae: 0.1119 - val_loss: 0.0198 - val_mae: 0.0708
# Epoch 75/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0290 - mae: 0.1133 - val_loss: 0.0212 - val_mae: 0.0799
# Epoch 76/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0292 - mae: 0.1126 - val_loss: 0.0215 - val_mae: 0.0835
# Epoch 77/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0293 - mae: 0.1135 - val_loss: 0.0200 - val_mae: 0.0746
# Epoch 78/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0286 - mae: 0.1116 - val_loss: 0.0201 - val_mae: 0.0783
# Epoch 79/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0280 - mae: 0.1104 - val_loss: 0.0201 - val_mae: 0.0722
# Epoch 80/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0289 - mae: 0.1130 - val_loss: 0.0203 - val_mae: 0.0751
# Epoch 81/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0284 - mae: 0.1109 - val_loss: 0.0214 - val_mae: 0.0828
# Epoch 82/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0284 - mae: 0.1114 - val_loss: 0.0199 - val_mae: 0.0729
# Epoch 83/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0282 - mae: 0.1106 - val_loss: 0.0196 - val_mae: 0.0730
# Epoch 84/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0288 - mae: 0.1125 - val_loss: 0.0197 - val_mae: 0.0721
# Epoch 85/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0287 - mae: 0.1115 - val_loss: 0.0215 - val_mae: 0.0816
# Epoch 86/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0283 - mae: 0.1105 - val_loss: 0.0199 - val_mae: 0.0738
# Epoch 87/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0283 - mae: 0.1117 - val_loss: 0.0207 - val_mae: 0.0779
# Epoch 88/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0287 - mae: 0.1111 - val_loss: 0.0201 - val_mae: 0.0724
# Epoch 89/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0279 - mae: 0.1097 - val_loss: 0.0229 - val_mae: 0.0906
# Epoch 90/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0280 - mae: 0.1099 - val_loss: 0.0200 - val_mae: 0.0711
# Epoch 91/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0280 - mae: 0.1100 - val_loss: 0.0204 - val_mae: 0.0779
# Epoch 92/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0284 - mae: 0.1107 - val_loss: 0.0202 - val_mae: 0.0726
# Epoch 93/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0283 - mae: 0.1104 - val_loss: 0.0196 - val_mae: 0.0709
# Epoch 94/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0279 - mae: 0.1094 - val_loss: 0.0199 - val_mae: 0.0746
# Epoch 95/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0278 - mae: 0.1097 - val_loss: 0.0195 - val_mae: 0.0710
# Epoch 96/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0278 - mae: 0.1093 - val_loss: 0.0203 - val_mae: 0.0711
# Epoch 97/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0287 - mae: 0.1109 - val_loss: 0.0210 - val_mae: 0.0806
# Epoch 98/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0272 - mae: 0.1086 - val_loss: 0.0213 - val_mae: 0.0806
# Epoch 99/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0282 - mae: 0.1100 - val_loss: 0.0210 - val_mae: 0.0793
# Epoch 100/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0282 - mae: 0.1100 - val_loss: 0.0218 - val_mae: 0.0864

# %%
y_pred= np.array(model.predict(X_test)).flatten()
y_test = np.array(y_test)
y_test, y_pred
# Out:
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# (array([1.94  , 1.283 , 1.919 , ..., 1.8725, 1.8365, 1.9655]),
#  array([1.9322411, 1.3046361, 1.8197469, ..., 1.8196934, 1.507827 ,
#         2.033157 ], dtype=float32))

# %%
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
relative_errors = np.abs((y_test - y_pred) / y_test) * 100
mean_relative_error = np.mean(relative_errors)
std_relative_error = np.std(relative_errors)

# %%
print("\n" + "="*50)
print("РЕЗУЛЬТАТЫ МОДЕЛИ")
print("="*50)
print(f"Mean Squared Error (MSE): {mse:.6f}")
print(f"Mean Absolute Error (MAE): {mae:.6f}")
print(f"Mean Absolute Per Error (MAPE): {mape:.6f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.6f}")
print(f"R² Score: {r2:.6f}")
# Out:
# ==================================================
# РЕЗУЛЬТАТЫ МОДЕЛИ
# ==================================================
# Mean Squared Error (MSE): 0.017542
# Mean Absolute Error (MAE): 0.070726
# Mean Absolute Per Error (MAPE): 0.065408
# Root Mean Squared Error (RMSE): 0.132448
# R² Score: 0.906362

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# 1. График обучения
axes[0, 0].plot(history.history['loss'], label='Train Loss')
axes[0, 0].plot(history.history['val_loss'], label='Validation Loss')
axes[0, 0].set_title('График обучения (Loss)')
axes[0, 0].set_xlabel('Эпохи')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].legend()
axes[0, 0].grid(True)

# 2. Сравнение предсказанных и реальных значений
axes[0, 1].scatter(y_test, y_pred, alpha=0.5)
axes[0, 1].plot([y_test.min(), y_test.max()], 
                [y_test.min(), y_test.max()], 'r--', lw=2)
axes[0, 1].set_title('Предсказанные vs Реальные значения')
axes[0, 1].set_xlabel(f'Реальные значения {target_cols}')
axes[0, 1].set_ylabel(f'Предсказанные значения {target_cols}')
axes[0, 1].grid(True)

# 3. Распределение ошибок
errors = y_test.flatten() - y_pred.flatten()
axes[1, 0].hist(errors, bins=50, edgecolor='black', alpha=0.7)
axes[1, 0].set_title('Распределение ошибок предсказания')
axes[1, 0].set_xlabel('Ошибка')
axes[1, 0].set_ylabel('Частота')
axes[1, 0].grid(True)

#
# 4. Распределение относительных ошибок
axes[1, 1].hist(relative_errors, bins=50, edgecolor='black', alpha=0.7, color='green')
axes[1, 1].axvline(mean_relative_error, color='red', linestyle='--', 
                   label=f'Средняя: {mean_relative_error:.2f}%')
axes[1, 1].axvline(mean_relative_error + std_relative_error, color='orange', 
                   linestyle=':', label=f'±1σ: {std_relative_error:.2f}%')
axes[1, 1].axvline(mean_relative_error - std_relative_error, color='orange', linestyle=':')
axes[1, 1].set_title('Распределение относительных ошибок')
axes[1, 1].set_xlabel('Относительная ошибка (%)')
axes[1, 1].set_ylabel('Частота')
axes[1, 1].legend()
axes[1, 1].grid(True)

plt.tight_layout()
plt.show()

# Дополнительная статистика
print("\n" + "="*50)
print("ДЕТАЛЬНАЯ СТАТИСТИКА")
print("="*50)
print(f"Минимальная относительная ошибка: {relative_errors.min():.2f}%")
print(f"Максимальная относительная ошибка: {relative_errors.max():.2f}%")
print(f"Медианная относительная ошибка: {np.median(relative_errors):.2f}%")
print(f"25-й перцентиль: {np.percentile(relative_errors, 25):.2f}%")
print(f"75-й перцентиль: {np.percentile(relative_errors, 75):.2f}%")


# Примеры предсказаний
print("\n" + "="*50)
print("ПРИМЕРЫ ПРЕДСКАЗАНИЙ (первые 10 тестовых образцов)")
print("="*50)
examples = pd.DataFrame({
    f'Реальный {target_cols}': y_test.flatten()[:10],
    f'Предсказанный {target_cols}': y_pred.flatten()[:10],
    'Абсолютная ошибка': np.abs(y_test.flatten()[:10] - y_pred.flatten()[:10]),
    'Относительная ошибка (%)': relative_errors.flatten()[:10]
})
print(examples.to_string(index=False))

# Сохранение модели
model.save(f'{target_cols}_prediction_model.h5')
print("\nМодель сохранена")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ==================================================
# ДЕТАЛЬНАЯ СТАТИСТИКА
# ==================================================
# Минимальная относительная ошибка: 0.00%
# Максимальная относительная ошибка: 193.05%
# Медианная относительная ошибка: 2.59%
# 25-й перцентиль: 1.29%
# 75-й перцентиль: 6.07%
#
# ==================================================
# ПРИМЕРЫ ПРЕДСКАЗАНИЙ (первые 10 тестовых образцов)
# ==================================================
#  Реальный K_E  Предсказанный K_E  Абсолютная ошибка  Относительная ошибка (%)
#        1.9400           1.932241           0.007759                  0.399944
#        1.2830           1.304636           0.021636                  1.686370
#        1.9190           1.819747           0.099253                  5.172129
#        0.8975           0.884042           0.013458                  1.499522
#        0.8330           0.868276           0.035276                  4.234807
#        0.7220           0.674390           0.047610                  6.594114
#        1.3940           1.415373           0.021373                  1.533194
#        0.8315           0.960298           0.128798                 15.489867
#        0.7865           0.808168           0.021668                  2.755012
#        1.5410           1.572745           0.031745                  2.060016
#
# Модель сохранена

# %%
accuracy_5_percent = np.mean(relative_errors < 5) * 100
print(f"Процент предсказаний с ошибкой < 5%: {accuracy_5_percent:.2f}%")
# Out:
# Процент предсказаний с ошибкой < 5%: 70.15%
