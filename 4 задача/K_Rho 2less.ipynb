# %%
target_cols = 'K_Rho'

output_file=f'{target_cols} determ.csv'
columns = ['K_Nu', 'K_E', 'K_Rho', 'K_incl', 'F', 'K_lambda_r', 'A2', 'А2_surface',  'Nu_host medium', 'E', 'Rho', 'Vp', 'Vs', 'Z']
p1, p2, p3 = 0.1, 10.0, 0.2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, callbacks
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, Input
from tensorflow.keras.optimizers import Adam

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
import pandas as pd
df = pd.read_csv(output_file)
df
# Out:
#         K_Nu     K_E  K_Rho  K_incl_top_position_y     F  K_lambda_r  \
# 0          1  0.5000      1                      1   0.1   10.000000
# 1          1  0.5000      1                      1   0.2    5.000000
# 2          1  0.5000      1                      1   0.3    3.333333
# 3          1  0.5000      1                      1   0.4    2.500000
# 4          1  0.5000      1                      1   0.5    2.000000
# ...      ...     ...    ...                    ...   ...         ...
# 100095     1  0.5135      1                      1   9.6    0.104167
# 100096     1  0.5135      1                      1   9.7    0.103093
# 100097     1  0.5135      1                      1   9.8    0.102041
# 100098     1  0.5135      1                      1   9.9    0.101010
# 100099     1  0.5135      1                      1  10.0    0.100000
#
#                   A2    А2_surface  Nu_host medium             E   Rho  \
# 0       5.331410e-13  5.331447e-13            0.25  5.000000e+10  2700
# 1       5.334885e-13  5.331474e-13            0.25  5.000000e+10  2700
# 2       5.367156e-13  5.363296e-13            0.25  5.000000e+10  2700
# 3       5.324516e-13  5.329968e-13            0.25  5.000000e+10  2700
# 4       5.332178e-13  5.322721e-13            0.25  5.000000e+10  2700
# ...              ...           ...             ...           ...   ...
# 100095  5.526740e-13  5.640118e-13            0.25  5.000000e+10  2700
# 100096  5.517025e-13  5.630990e-13            0.25  5.000000e+10  2700
# 100097  5.508005e-13  5.622432e-13            0.25  5.000000e+10  2700
# 100098  5.499630e-13  5.614406e-13            0.25  5.000000e+10  2700
# 100099  5.492409e-13  5.606671e-13            0.25  5.000000e+10  2700
#
#                  Vp           Vs            Z
# 0       3333.333333  1924.500897  2502.294446
# 1       3333.333333  1924.500897  2502.294446
# 2       3333.333333  1924.500897  2502.294446
# 3       3333.333333  1924.500897  2502.294446
# 4       3333.333333  1924.500897  2502.294446
# ...             ...          ...          ...
# 100095  3378.033616  1950.308618  2502.294446
# 100096  3378.033616  1950.308618  2502.294446
# 100097  3378.033616  1950.308618  2502.294446
# 100098  3378.033616  1950.308618  2502.294446
# 100099  3378.033616  1950.308618  2502.294446
#
# [100100 rows x 14 columns]

# %%
delete_values = np.arange(p1, p2, p3).round(1).tolist()
df = df[df['F'].round(1).isin(delete_values)]

# %%
df['A2/A2_s'] = df['A2'] / df['А2_surface']
y = df[target_cols]
X = df[['A2/A2_s', 'F']]
X[:5]
# Out:
# C:\Users\1\AppData\Local\Temp\ipykernel_20148\3331272413.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['A2/A2_s'] = df['A2'] / df['А2_surface']
#     A2/A2_s    F
# 0  0.999993  0.1
# 2  1.000720  0.3
# 4  1.001777  0.5
# 6  1.032819  0.7
# 8  1.059318  0.9

# %%
scaler_X = StandardScaler()

X_scaled = scaler_X.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
model = Sequential([
    Dense(128, activation='relu', input_shape=(2,), name='hidden_layer_1'),
    Dropout(0.2),  # Добавляем Dropout для регуляризации
    Dense(64, activation='relu', name='hidden_layer_2'),
    Dropout(0.2),
    Dense(1, name='output_layer')
])
# Out:
# C:\Users\1\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='mse',
    metrics=['mae']
)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ hidden_layer_1 (Dense)          │ (None, 128)            │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden_layer_2 (Dense)          │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,705 (34.00 KB)
#  Trainable params: 8,705 (34.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Ранняя остановка для предотвращения переобучения
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True
)

# Обучение модели
history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1677 - mae: 0.3139 - val_loss: 0.0745 - val_mae: 0.1999
# Epoch 2/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0879 - mae: 0.2255 - val_loss: 0.0571 - val_mae: 0.1613
# Epoch 3/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0750 - mae: 0.2029 - val_loss: 0.0519 - val_mae: 0.1484
# Epoch 4/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0664 - mae: 0.1881 - val_loss: 0.0489 - val_mae: 0.1475
# Epoch 5/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0612 - mae: 0.1786 - val_loss: 0.0479 - val_mae: 0.1426
# Epoch 6/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0563 - mae: 0.1693 - val_loss: 0.0441 - val_mae: 0.1284
# Epoch 7/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0538 - mae: 0.1637 - val_loss: 0.0418 - val_mae: 0.1280
# Epoch 8/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0512 - mae: 0.1584 - val_loss: 0.0400 - val_mae: 0.1213
# Epoch 9/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0492 - mae: 0.1541 - val_loss: 0.0392 - val_mae: 0.1215
# Epoch 10/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0485 - mae: 0.1522 - val_loss: 0.0384 - val_mae: 0.1209
# Epoch 11/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0473 - mae: 0.1498 - val_loss: 0.0376 - val_mae: 0.1160
# Epoch 12/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0463 - mae: 0.1468 - val_loss: 0.0397 - val_mae: 0.1230
# Epoch 13/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0459 - mae: 0.1460 - val_loss: 0.0378 - val_mae: 0.1136
# Epoch 14/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0451 - mae: 0.1441 - val_loss: 0.0353 - val_mae: 0.1065
# Epoch 15/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0447 - mae: 0.1432 - val_loss: 0.0366 - val_mae: 0.1192
# Epoch 16/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0441 - mae: 0.1421 - val_loss: 0.0344 - val_mae: 0.1057
# Epoch 17/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0435 - mae: 0.1403 - val_loss: 0.0342 - val_mae: 0.1047
# Epoch 18/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0427 - mae: 0.1390 - val_loss: 0.0397 - val_mae: 0.1225
# Epoch 19/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0430 - mae: 0.1388 - val_loss: 0.0346 - val_mae: 0.1042
# Epoch 20/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0422 - mae: 0.1381 - val_loss: 0.0355 - val_mae: 0.1119
# Epoch 21/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0421 - mae: 0.1368 - val_loss: 0.0339 - val_mae: 0.1058
# Epoch 22/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0416 - mae: 0.1364 - val_loss: 0.0343 - val_mae: 0.1067
# Epoch 23/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0416 - mae: 0.1358 - val_loss: 0.0367 - val_mae: 0.1147
# Epoch 24/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0411 - mae: 0.1346 - val_loss: 0.0351 - val_mae: 0.1039
# Epoch 25/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0411 - mae: 0.1344 - val_loss: 0.0324 - val_mae: 0.1004
# Epoch 26/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0412 - mae: 0.1344 - val_loss: 0.0341 - val_mae: 0.1057
# Epoch 27/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0411 - mae: 0.1344 - val_loss: 0.0346 - val_mae: 0.1084
# Epoch 28/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0406 - mae: 0.1333 - val_loss: 0.0327 - val_mae: 0.1005
# Epoch 29/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0406 - mae: 0.1328 - val_loss: 0.0340 - val_mae: 0.1052
# Epoch 30/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0406 - mae: 0.1335 - val_loss: 0.0329 - val_mae: 0.1005
# Epoch 31/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0401 - mae: 0.1320 - val_loss: 0.0341 - val_mae: 0.1032
# Epoch 32/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0399 - mae: 0.1315 - val_loss: 0.0351 - val_mae: 0.1050
# Epoch 33/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0402 - mae: 0.1320 - val_loss: 0.0344 - val_mae: 0.1088
# Epoch 34/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0399 - mae: 0.1319 - val_loss: 0.0329 - val_mae: 0.0984
# Epoch 35/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0396 - mae: 0.1315 - val_loss: 0.0330 - val_mae: 0.0989
# Epoch 36/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0399 - mae: 0.1312 - val_loss: 0.0323 - val_mae: 0.1012
# Epoch 37/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0403 - mae: 0.1319 - val_loss: 0.0330 - val_mae: 0.1020
# Epoch 38/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0389 - mae: 0.1296 - val_loss: 0.0333 - val_mae: 0.1006
# Epoch 39/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0395 - mae: 0.1307 - val_loss: 0.0326 - val_mae: 0.1009
# Epoch 40/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0393 - mae: 0.1303 - val_loss: 0.0362 - val_mae: 0.1129
# Epoch 41/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0390 - mae: 0.1297 - val_loss: 0.0314 - val_mae: 0.0973
# Epoch 42/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0391 - mae: 0.1298 - val_loss: 0.0333 - val_mae: 0.1064
# Epoch 43/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0389 - mae: 0.1291 - val_loss: 0.0347 - val_mae: 0.1050
# Epoch 44/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0391 - mae: 0.1296 - val_loss: 0.0325 - val_mae: 0.1002
# Epoch 45/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0392 - mae: 0.1295 - val_loss: 0.0322 - val_mae: 0.1027
# Epoch 46/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0386 - mae: 0.1286 - val_loss: 0.0315 - val_mae: 0.0979
# Epoch 47/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0383 - mae: 0.1284 - val_loss: 0.0335 - val_mae: 0.1094
# Epoch 48/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0388 - mae: 0.1296 - val_loss: 0.0319 - val_mae: 0.1018
# Epoch 49/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0390 - mae: 0.1292 - val_loss: 0.0323 - val_mae: 0.1072
# Epoch 50/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0386 - mae: 0.1282 - val_loss: 0.0321 - val_mae: 0.1035
# Epoch 51/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0381 - mae: 0.1270 - val_loss: 0.0319 - val_mae: 0.0964
# Epoch 52/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0384 - mae: 0.1281 - val_loss: 0.0322 - val_mae: 0.1079
# Epoch 53/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0387 - mae: 0.1287 - val_loss: 0.0321 - val_mae: 0.1053
# Epoch 54/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0382 - mae: 0.1276 - val_loss: 0.0364 - val_mae: 0.1157
# Epoch 55/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0385 - mae: 0.1281 - val_loss: 0.0321 - val_mae: 0.0983
# Epoch 56/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0381 - mae: 0.1276 - val_loss: 0.0365 - val_mae: 0.1122
# Epoch 57/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0382 - mae: 0.1273 - val_loss: 0.0322 - val_mae: 0.1036
# Epoch 58/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0378 - mae: 0.1270 - val_loss: 0.0323 - val_mae: 0.0986
# Epoch 59/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0380 - mae: 0.1265 - val_loss: 0.0315 - val_mae: 0.0982
# Epoch 60/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0379 - mae: 0.1268 - val_loss: 0.0321 - val_mae: 0.1017
# Epoch 61/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0380 - mae: 0.1263 - val_loss: 0.0323 - val_mae: 0.1039

# %%
y_pred= np.array(model.predict(X_test)).flatten()
y_test = np.array(y_test)
y_test, y_pred
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# (array([1.226 , 0.7355, 1.9445, ..., 1.733 , 1.8095, 1.2215]),
#  array([1.1415079 , 0.77727485, 1.8117151 , ..., 1.8023238 , 1.8318512 ,
#         1.4080591 ], dtype=float32))

# %%
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
relative_errors = np.abs((y_test - y_pred) / y_test) * 100
mean_relative_error = np.mean(relative_errors)
std_relative_error = np.std(relative_errors)

# %%
print("\n" + "="*50)
print("РЕЗУЛЬТАТЫ МОДЕЛИ")
print("="*50)
print(f"Mean Squared Error (MSE): {mse:.6f}")
print(f"Mean Absolute Error (MAE): {mae:.6f}")
print(f"Mean Absolute Per Error (MAPE): {mape:.6f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.6f}")
print(f"R² Score: {r2:.6f}")
# Out:
# ==================================================
# РЕЗУЛЬТАТЫ МОДЕЛИ
# ==================================================
# Mean Squared Error (MSE): 0.031851
# Mean Absolute Error (MAE): 0.098792
# Mean Absolute Per Error (MAPE): 0.095730
# Root Mean Squared Error (RMSE): 0.178470
# R² Score: 0.831054

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# 1. График обучения
axes[0, 0].plot(history.history['loss'], label='Train Loss')
axes[0, 0].plot(history.history['val_loss'], label='Validation Loss')
axes[0, 0].set_title('График обучения (Loss)')
axes[0, 0].set_xlabel('Эпохи')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].legend()
axes[0, 0].grid(True)

# 2. Сравнение предсказанных и реальных значений
axes[0, 1].scatter(y_test, y_pred, alpha=0.5)
axes[0, 1].plot([y_test.min(), y_test.max()], 
                [y_test.min(), y_test.max()], 'r--', lw=2)
axes[0, 1].set_title('Предсказанные vs Реальные значения')
axes[0, 1].set_xlabel(f'Реальные значения {target_cols}')
axes[0, 1].set_ylabel(f'Предсказанные значения {target_cols}')
axes[0, 1].grid(True)

# 3. Распределение ошибок
errors = y_test.flatten() - y_pred.flatten()
axes[1, 0].hist(errors, bins=50, edgecolor='black', alpha=0.7)
axes[1, 0].set_title('Распределение ошибок предсказания')
axes[1, 0].set_xlabel('Ошибка')
axes[1, 0].set_ylabel('Частота')
axes[1, 0].grid(True)

#
# 4. Распределение относительных ошибок
axes[1, 1].hist(relative_errors, bins=50, edgecolor='black', alpha=0.7, color='green')
axes[1, 1].axvline(mean_relative_error, color='red', linestyle='--', 
                   label=f'Средняя: {mean_relative_error:.2f}%')
axes[1, 1].axvline(mean_relative_error + std_relative_error, color='orange', 
                   linestyle=':', label=f'±1σ: {std_relative_error:.2f}%')
axes[1, 1].axvline(mean_relative_error - std_relative_error, color='orange', linestyle=':')
axes[1, 1].set_title('Распределение относительных ошибок')
axes[1, 1].set_xlabel('Относительная ошибка (%)')
axes[1, 1].set_ylabel('Частота')
axes[1, 1].legend()
axes[1, 1].grid(True)

plt.tight_layout()
plt.show()

# Дополнительная статистика
print("\n" + "="*50)
print("ДЕТАЛЬНАЯ СТАТИСТИКА")
print("="*50)
print(f"Минимальная относительная ошибка: {relative_errors.min():.2f}%")
print(f"Максимальная относительная ошибка: {relative_errors.max():.2f}%")
print(f"Медианная относительная ошибка: {np.median(relative_errors):.2f}%")
print(f"25-й перцентиль: {np.percentile(relative_errors, 25):.2f}%")
print(f"75-й перцентиль: {np.percentile(relative_errors, 75):.2f}%")


# Примеры предсказаний
print("\n" + "="*50)
print("ПРИМЕРЫ ПРЕДСКАЗАНИЙ (первые 10 тестовых образцов)")
print("="*50)
examples = pd.DataFrame({
    f'Реальный {target_cols}': y_test.flatten()[:10],
    f'Предсказанный {target_cols}': y_pred.flatten()[:10],
    'Абсолютная ошибка': np.abs(y_test.flatten()[:10] - y_pred.flatten()[:10]),
    'Относительная ошибка (%)': relative_errors.flatten()[:10]
})
print(examples.to_string(index=False))

# Сохранение модели
model.save(f'{target_cols}_prediction_model.h5')
print("\nМодель сохранена")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ==================================================
# ДЕТАЛЬНАЯ СТАТИСТИКА
# ==================================================
# Минимальная относительная ошибка: 0.00%
# Максимальная относительная ошибка: 232.91%
# Медианная относительная ошибка: 3.55%
# 25-й перцентиль: 1.54%
# 75-й перцентиль: 8.78%
#
# ==================================================
# ПРИМЕРЫ ПРЕДСКАЗАНИЙ (первые 10 тестовых образцов)
# ==================================================
#  Реальный K_E  Предсказанный K_E  Абсолютная ошибка  Относительная ошибка (%)
#        1.2260           1.141508           0.084492                  6.891691
#        0.7355           0.777275           0.041775                  5.679789
#        1.9445           1.811715           0.132785                  6.828741
#        0.9440           1.192132           0.248132                 26.285220
#        0.6020           1.091750           0.489750                 81.353825
#        0.9920           0.968140           0.023860                  2.405229
#        1.9940           1.421160           0.572840                 28.728185
#        1.2545           1.252431           0.002069                  0.164952
#        1.3775           1.194412           0.183088                 13.291291
#        1.1855           1.219563           0.034063                  2.873333
#
# Модель сохранена

# %%
accuracy_5_percent = np.mean(relative_errors < 5) * 100
print(f"Процент предсказаний с ошибкой < 5%: {accuracy_5_percent:.2f}%")
# Out:
# Процент предсказаний с ошибкой < 5%: 61.08%
