# %%
target_cols = 'K_Nu'

output_file=f'{target_cols} determ.csv'
columns = ['K_Nu', 'K_E', 'K_Rho', 'K_incl', 'F', 'K_lambda_r', 'A2', 'А2_surface',  'Nu_host medium', 'E', 'Rho', 'Vp', 'Vs', 'Z']
p1, p2, p3 = 0.1, 10.0, 0.2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, callbacks
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, Input
from tensorflow.keras.optimizers import Adam
# Out:
# C:\Users\1\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
import pandas as pd
df = pd.read_csv(output_file)
df
# Out:
#           K_Nu  K_E  K_Rho  K_incl_top_position_y     F  K_lambda_r  \
# 0       0.8000    1      1                      1   0.1   10.000000
# 1       0.8000    1      1                      1   0.2    5.000000
# 2       0.8000    1      1                      1   0.3    3.333333
# 3       0.8000    1      1                      1   0.4    2.500000
# 4       0.8000    1      1                      1   0.5    2.000000
# ...        ...  ...    ...                    ...   ...         ...
# 100095  0.8036    1      1                      1   9.6    0.104167
# 100096  0.8036    1      1                      1   9.7    0.103093
# 100097  0.8036    1      1                      1   9.8    0.102041
# 100098  0.8036    1      1                      1   9.9    0.101010
# 100099  0.8036    1      1                      1  10.0    0.100000
#
#                   A2    А2_surface  Nu_host medium             E   Rho  \
# 0       5.331371e-13  5.331386e-13            0.25  5.000000e+10  2700
# 1       5.334869e-13  5.331507e-13            0.25  5.000000e+10  2700
# 2       5.366543e-13  5.363065e-13            0.25  5.000000e+10  2700
# 3       5.329471e-13  5.332102e-13            0.25  5.000000e+10  2700
# 4       5.331205e-13  5.332521e-13            0.25  5.000000e+10  2700
# ...              ...           ...             ...           ...   ...
# 100095  5.367186e-13  5.358007e-13            0.25  5.000000e+10  2700
# 100096  5.369076e-13  5.359525e-13            0.25  5.000000e+10  2700
# 100097  5.370946e-13  5.361025e-13            0.25  5.000000e+10  2700
# 100098  5.372790e-13  5.362506e-13            0.25  5.000000e+10  2700
# 100099  5.375364e-13  5.364468e-13            0.25  5.000000e+10  2700
#
#                  Vp           Vs            Z
# 0       4536.092116  2777.777778  2502.294446
# 1       4536.092116  2777.777778  2502.294446
# 2       4536.092116  2777.777778  2502.294446
# 3       4536.092116  2777.777778  2502.294446
# 4       4536.092116  2777.777778  2502.294446
# ...             ...          ...          ...
# 100095  4538.653819  2776.736697  2502.294446
# 100096  4538.653819  2776.736697  2502.294446
# 100097  4538.653819  2776.736697  2502.294446
# 100098  4538.653819  2776.736697  2502.294446
# 100099  4538.653819  2776.736697  2502.294446
#
# [100100 rows x 14 columns]

# %%
delete_values = np.arange(p1, p2, p3).round(1).tolist()
df = df[df['F'].round(1).isin(delete_values)]

# %%
df['A2/A2_s'] = df['A2'] / df['А2_surface']
y = df[target_cols]
X = df[['A2/A2_s', 'F']]
X[:5]
# Out:
# C:\Users\1\AppData\Local\Temp\ipykernel_20276\3331272413.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['A2/A2_s'] = df['A2'] / df['А2_surface']
#     A2/A2_s    F
# 0  0.999997  0.1
# 2  1.000649  0.3
# 4  0.999753  0.5
# 6  0.998032  0.7
# 8  0.995067  0.9

# %%
scaler_X = StandardScaler()

X_scaled = scaler_X.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
model = Sequential([
    Dense(128, activation='relu', input_shape=(2,), name='hidden_layer_1'),
    Dropout(0.2),  # Добавляем Dropout для регуляризации
    Dense(64, activation='relu', name='hidden_layer_2'),
    Dropout(0.2),
    Dense(1, name='output_layer')
])
# Out:
# C:\Users\1\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='mse',
    metrics=['mae']
)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ hidden_layer_1 (Dense)          │ (None, 128)            │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden_layer_2 (Dense)          │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,705 (34.00 KB)
#  Trainable params: 8,705 (34.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Ранняя остановка для предотвращения переобучения
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True
)

# Обучение модели
history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0321 - mae: 0.1273 - val_loss: 0.0062 - val_mae: 0.0599
# Epoch 2/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0113 - mae: 0.0835 - val_loss: 0.0047 - val_mae: 0.0466
# Epoch 3/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0083 - mae: 0.0705 - val_loss: 0.0041 - val_mae: 0.0405
# Epoch 4/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0063 - mae: 0.0604 - val_loss: 0.0038 - val_mae: 0.0389
# Epoch 5/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0050 - mae: 0.0525 - val_loss: 0.0034 - val_mae: 0.0352
# Epoch 6/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0043 - mae: 0.0471 - val_loss: 0.0033 - val_mae: 0.0404
# Epoch 7/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0038 - mae: 0.0433 - val_loss: 0.0031 - val_mae: 0.0370
# Epoch 8/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0036 - mae: 0.0417 - val_loss: 0.0030 - val_mae: 0.0354
# Epoch 9/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0034 - mae: 0.0403 - val_loss: 0.0034 - val_mae: 0.0349
# Epoch 10/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0033 - mae: 0.0391 - val_loss: 0.0027 - val_mae: 0.0324
# Epoch 11/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0032 - mae: 0.0386 - val_loss: 0.0024 - val_mae: 0.0290
# Epoch 12/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0031 - mae: 0.0378 - val_loss: 0.0025 - val_mae: 0.0322
# Epoch 13/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0030 - mae: 0.0373 - val_loss: 0.0023 - val_mae: 0.0296
# Epoch 14/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0029 - mae: 0.0367 - val_loss: 0.0024 - val_mae: 0.0299
# Epoch 15/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0029 - mae: 0.0365 - val_loss: 0.0023 - val_mae: 0.0280
# Epoch 16/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0029 - mae: 0.0363 - val_loss: 0.0021 - val_mae: 0.0272
# Epoch 17/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0028 - mae: 0.0360 - val_loss: 0.0023 - val_mae: 0.0305
# Epoch 18/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0028 - mae: 0.0357 - val_loss: 0.0024 - val_mae: 0.0309
# Epoch 19/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0027 - mae: 0.0352 - val_loss: 0.0020 - val_mae: 0.0266
# Epoch 20/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0027 - mae: 0.0350 - val_loss: 0.0024 - val_mae: 0.0306
# Epoch 21/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0026 - mae: 0.0348 - val_loss: 0.0021 - val_mae: 0.0270
# Epoch 22/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0026 - mae: 0.0347 - val_loss: 0.0019 - val_mae: 0.0266
# Epoch 23/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0026 - mae: 0.0342 - val_loss: 0.0019 - val_mae: 0.0253
# Epoch 24/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 0.0025 - mae: 0.0342 - val_loss: 0.0021 - val_mae: 0.0302
# Epoch 25/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0025 - mae: 0.0340 - val_loss: 0.0018 - val_mae: 0.0252
# Epoch 26/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0025 - mae: 0.0341 - val_loss: 0.0020 - val_mae: 0.0263
# Epoch 27/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0026 - mae: 0.0341 - val_loss: 0.0019 - val_mae: 0.0273
# Epoch 28/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0025 - mae: 0.0340 - val_loss: 0.0019 - val_mae: 0.0268
# Epoch 29/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0025 - mae: 0.0339 - val_loss: 0.0019 - val_mae: 0.0249
# Epoch 30/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0025 - mae: 0.0340 - val_loss: 0.0019 - val_mae: 0.0264
# Epoch 31/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0025 - mae: 0.0338 - val_loss: 0.0020 - val_mae: 0.0262
# Epoch 32/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0025 - mae: 0.0340 - val_loss: 0.0019 - val_mae: 0.0249
# Epoch 33/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0025 - mae: 0.0336 - val_loss: 0.0018 - val_mae: 0.0246
# Epoch 34/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0025 - mae: 0.0334 - val_loss: 0.0019 - val_mae: 0.0247
# Epoch 35/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0025 - mae: 0.0335 - val_loss: 0.0019 - val_mae: 0.0269
# Epoch 36/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0025 - mae: 0.0335 - val_loss: 0.0017 - val_mae: 0.0231
# Epoch 37/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0025 - mae: 0.0338 - val_loss: 0.0020 - val_mae: 0.0298
# Epoch 38/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0025 - mae: 0.0335 - val_loss: 0.0018 - val_mae: 0.0256
# Epoch 39/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0025 - mae: 0.0334 - val_loss: 0.0018 - val_mae: 0.0255
# Epoch 40/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0025 - mae: 0.0335 - val_loss: 0.0019 - val_mae: 0.0262
# Epoch 41/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0025 - mae: 0.0334 - val_loss: 0.0019 - val_mae: 0.0262
# Epoch 42/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0024 - mae: 0.0333 - val_loss: 0.0021 - val_mae: 0.0280
# Epoch 43/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0024 - mae: 0.0330 - val_loss: 0.0020 - val_mae: 0.0283
# Epoch 44/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0025 - mae: 0.0334 - val_loss: 0.0020 - val_mae: 0.0284
# Epoch 45/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0024 - mae: 0.0331 - val_loss: 0.0020 - val_mae: 0.0259
# Epoch 46/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0024 - mae: 0.0329 - val_loss: 0.0019 - val_mae: 0.0266
# Epoch 47/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0024 - mae: 0.0332 - val_loss: 0.0019 - val_mae: 0.0284
# Epoch 48/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0024 - mae: 0.0329 - val_loss: 0.0018 - val_mae: 0.0271
# Epoch 49/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0024 - mae: 0.0327 - val_loss: 0.0018 - val_mae: 0.0249
# Epoch 50/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0024 - mae: 0.0330 - val_loss: 0.0017 - val_mae: 0.0258
# Epoch 51/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0024 - mae: 0.0329 - val_loss: 0.0020 - val_mae: 0.0279
# Epoch 52/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0024 - mae: 0.0329 - val_loss: 0.0018 - val_mae: 0.0258
# Epoch 53/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0025 - mae: 0.0331 - val_loss: 0.0017 - val_mae: 0.0244
# Epoch 54/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0024 - mae: 0.0329 - val_loss: 0.0018 - val_mae: 0.0268
# Epoch 55/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0024 - mae: 0.0329 - val_loss: 0.0017 - val_mae: 0.0246
# Epoch 56/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0024 - mae: 0.0327 - val_loss: 0.0017 - val_mae: 0.0241
# Epoch 57/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0024 - mae: 0.0328 - val_loss: 0.0018 - val_mae: 0.0238
# Epoch 58/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0024 - mae: 0.0326 - val_loss: 0.0019 - val_mae: 0.0276
# Epoch 59/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0024 - mae: 0.0325 - val_loss: 0.0019 - val_mae: 0.0266
# Epoch 60/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0024 - mae: 0.0327 - val_loss: 0.0018 - val_mae: 0.0268
# Epoch 61/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0024 - mae: 0.0325 - val_loss: 0.0017 - val_mae: 0.0231
# Epoch 62/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0024 - mae: 0.0327 - val_loss: 0.0017 - val_mae: 0.0237
# Epoch 63/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0024 - mae: 0.0326 - val_loss: 0.0019 - val_mae: 0.0284
# Epoch 64/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0024 - mae: 0.0325 - val_loss: 0.0017 - val_mae: 0.0259
# Epoch 65/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0023 - mae: 0.0323 - val_loss: 0.0017 - val_mae: 0.0251
# Epoch 66/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0023 - mae: 0.0323 - val_loss: 0.0018 - val_mae: 0.0259
# Epoch 67/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0024 - mae: 0.0327 - val_loss: 0.0017 - val_mae: 0.0268
# Epoch 68/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0023 - mae: 0.0321 - val_loss: 0.0018 - val_mae: 0.0246
# Epoch 69/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0023 - mae: 0.0323 - val_loss: 0.0016 - val_mae: 0.0221
# Epoch 70/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0023 - mae: 0.0321 - val_loss: 0.0016 - val_mae: 0.0228
# Epoch 71/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0023 - mae: 0.0320 - val_loss: 0.0017 - val_mae: 0.0250
# Epoch 72/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0023 - mae: 0.0323 - val_loss: 0.0017 - val_mae: 0.0248
# Epoch 73/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0023 - mae: 0.0322 - val_loss: 0.0018 - val_mae: 0.0266
# Epoch 74/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0023 - mae: 0.0320 - val_loss: 0.0016 - val_mae: 0.0219
# Epoch 75/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0023 - mae: 0.0322 - val_loss: 0.0017 - val_mae: 0.0251
# Epoch 76/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0023 - mae: 0.0317 - val_loss: 0.0019 - val_mae: 0.0286
# Epoch 77/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0023 - mae: 0.0319 - val_loss: 0.0017 - val_mae: 0.0260
# Epoch 78/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0023 - mae: 0.0320 - val_loss: 0.0018 - val_mae: 0.0259
# Epoch 79/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0023 - mae: 0.0321 - val_loss: 0.0015 - val_mae: 0.0217
# Epoch 80/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0023 - mae: 0.0322 - val_loss: 0.0018 - val_mae: 0.0258
# Epoch 81/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0023 - mae: 0.0318 - val_loss: 0.0016 - val_mae: 0.0236
# Epoch 82/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0023 - mae: 0.0318 - val_loss: 0.0017 - val_mae: 0.0243
# Epoch 83/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0023 - mae: 0.0319 - val_loss: 0.0018 - val_mae: 0.0257
# Epoch 84/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0023 - mae: 0.0319 - val_loss: 0.0017 - val_mae: 0.0248
# Epoch 85/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0023 - mae: 0.0318 - val_loss: 0.0016 - val_mae: 0.0252
# Epoch 86/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0023 - mae: 0.0319 - val_loss: 0.0017 - val_mae: 0.0255
# Epoch 87/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0023 - mae: 0.0319 - val_loss: 0.0016 - val_mae: 0.0240
# Epoch 88/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0023 - mae: 0.0317 - val_loss: 0.0016 - val_mae: 0.0234
# Epoch 89/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0023 - mae: 0.0319 - val_loss: 0.0016 - val_mae: 0.0236
# Epoch 90/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0023 - mae: 0.0316 - val_loss: 0.0017 - val_mae: 0.0247
# Epoch 91/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0023 - mae: 0.0317 - val_loss: 0.0018 - val_mae: 0.0267
# Epoch 92/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0023 - mae: 0.0318 - val_loss: 0.0015 - val_mae: 0.0228
# Epoch 93/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0023 - mae: 0.0318 - val_loss: 0.0019 - val_mae: 0.0258
# Epoch 94/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0022 - mae: 0.0316 - val_loss: 0.0018 - val_mae: 0.0266
# Epoch 95/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0022 - mae: 0.0316 - val_loss: 0.0021 - val_mae: 0.0275
# Epoch 96/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0023 - mae: 0.0318 - val_loss: 0.0017 - val_mae: 0.0253
# Epoch 97/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0022 - mae: 0.0313 - val_loss: 0.0017 - val_mae: 0.0246
# Epoch 98/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0022 - mae: 0.0314 - val_loss: 0.0017 - val_mae: 0.0252
# Epoch 99/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0023 - mae: 0.0315 - val_loss: 0.0018 - val_mae: 0.0271

# %%
y_pred= np.array(model.predict(X_test)).flatten()
y_test = np.array(y_test)
y_test, y_pred
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# (array([0.9936, 0.8628, 1.1852, ..., 1.1288, 1.1492, 0.9924]),
#  array([0.9662093 , 0.86186814, 1.1517489 , ..., 1.1144015 , 1.1589439 ,
#         1.0368948 ], dtype=float32))

# %%
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
relative_errors = np.abs((y_test - y_pred) / y_test) * 100
mean_relative_error = np.mean(relative_errors)
std_relative_error = np.std(relative_errors)

# %%
print("\n" + "="*50)
print("РЕЗУЛЬТАТЫ МОДЕЛИ")
print("="*50)
print(f"Mean Squared Error (MSE): {mse:.6f}")
print(f"Mean Absolute Error (MAE): {mae:.6f}")
print(f"Mean Absolute Per Error (MAPE): {mape:.6f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.6f}")
print(f"R² Score: {r2:.6f}")
# Out:
# ==================================================
# РЕЗУЛЬТАТЫ МОДЕЛИ
# ==================================================
# Mean Squared Error (MSE): 0.001603
# Mean Absolute Error (MAE): 0.022190
# Mean Absolute Per Error (MAPE): 0.022788
# Root Mean Squared Error (RMSE): 0.040036
# R² Score: 0.880441

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# 1. График обучения
axes[0, 0].plot(history.history['loss'], label='Train Loss')
axes[0, 0].plot(history.history['val_loss'], label='Validation Loss')
axes[0, 0].set_title('График обучения (Loss)')
axes[0, 0].set_xlabel('Эпохи')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].legend()
axes[0, 0].grid(True)

# 2. Сравнение предсказанных и реальных значений
axes[0, 1].scatter(y_test, y_pred, alpha=0.5)
axes[0, 1].plot([y_test.min(), y_test.max()], 
                [y_test.min(), y_test.max()], 'r--', lw=2)
axes[0, 1].set_title('Предсказанные vs Реальные значения')
axes[0, 1].set_xlabel(f'Реальные значения {target_cols}')
axes[0, 1].set_ylabel(f'Предсказанные значения {target_cols}')
axes[0, 1].grid(True)

# 3. Распределение ошибок
errors = y_test.flatten() - y_pred.flatten()
axes[1, 0].hist(errors, bins=50, edgecolor='black', alpha=0.7)
axes[1, 0].set_title('Распределение ошибок предсказания')
axes[1, 0].set_xlabel('Ошибка')
axes[1, 0].set_ylabel('Частота')
axes[1, 0].grid(True)

#
# 4. Распределение относительных ошибок
axes[1, 1].hist(relative_errors, bins=50, edgecolor='black', alpha=0.7, color='green')
axes[1, 1].axvline(mean_relative_error, color='red', linestyle='--', 
                   label=f'Средняя: {mean_relative_error:.2f}%')
axes[1, 1].axvline(mean_relative_error + std_relative_error, color='orange', 
                   linestyle=':', label=f'±1σ: {std_relative_error:.2f}%')
axes[1, 1].axvline(mean_relative_error - std_relative_error, color='orange', linestyle=':')
axes[1, 1].set_title('Распределение относительных ошибок')
axes[1, 1].set_xlabel('Относительная ошибка (%)')
axes[1, 1].set_ylabel('Частота')
axes[1, 1].legend()
axes[1, 1].grid(True)

plt.tight_layout()
plt.show()

# Дополнительная статистика
print("\n" + "="*50)
print("ДЕТАЛЬНАЯ СТАТИСТИКА")
print("="*50)
print(f"Минимальная относительная ошибка: {relative_errors.min():.2f}%")
print(f"Максимальная относительная ошибка: {relative_errors.max():.2f}%")
print(f"Медианная относительная ошибка: {np.median(relative_errors):.2f}%")
print(f"25-й перцентиль: {np.percentile(relative_errors, 25):.2f}%")
print(f"75-й перцентиль: {np.percentile(relative_errors, 75):.2f}%")


# Примеры предсказаний
print("\n" + "="*50)
print("ПРИМЕРЫ ПРЕДСКАЗАНИЙ (первые 10 тестовых образцов)")
print("="*50)
examples = pd.DataFrame({
    f'Реальный {target_cols}': y_test.flatten()[:10],
    f'Предсказанный {target_cols}': y_pred.flatten()[:10],
    'Абсолютная ошибка': np.abs(y_test.flatten()[:10] - y_pred.flatten()[:10]),
    'Относительная ошибка (%)': relative_errors.flatten()[:10]
})
print(examples.to_string(index=False))

# Сохранение модели
model.save(f'{target_cols}_prediction_model.h5')
print("\nМодель сохранена")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ==================================================
# ДЕТАЛЬНАЯ СТАТИСТИКА
# ==================================================
# Минимальная относительная ошибка: 0.00%
# Максимальная относительная ошибка: 25.47%
# Медианная относительная ошибка: 0.83%
# 25-й перцентиль: 0.38%
# 75-й перцентиль: 2.53%
#
# ==================================================
# ПРИМЕРЫ ПРЕДСКАЗАНИЙ (первые 10 тестовых образцов)
# ==================================================
#  Реальный K_Nu  Предсказанный K_Nu  Абсолютная ошибка  Относительная ошибка (%)
#         0.9936            0.966209           0.027391                  2.756714
#         0.8628            0.861868           0.000932                  0.108004
#         1.1852            1.151749           0.033451                  2.822402
#         0.9184            1.002356           0.083956                  9.141556
#         0.8272            0.959451           0.132251                 15.987807
#         0.9312            0.935452           0.004252                  0.456601
#         1.1984            1.191311           0.007089                  0.591529
#         1.0012            1.012652           0.011452                  1.143796
#         1.0340            1.002517           0.031483                  3.044791
#         0.9828            0.987358           0.004558                  0.463811
#
# Модель сохранена

# %%
accuracy_5_percent = np.mean(relative_errors < 5) * 100
print(f"Процент предсказаний с ошибкой < 5%: {accuracy_5_percent:.2f}%")
# Out:
# Процент предсказаний с ошибкой < 5%: 86.40%
