# %%
target_cols = 'K_Nu'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score,mean_absolute_percentage_error
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, callbacks
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import os

input_folder=f'C:/Users/1/projects/zadachi/2 задача/{target_cols} random'
output_file=f'{target_cols} random.csv'
columns = ['K_Nu', 'K_E', 'K_Rho', 'K_incl', 'F', 'K_lambda_r', 'A2', 'А2_surface',  'Nu_host medium', 'E', 'Rho', 'Vp', 'Vs', 'Z']
# Out:
# C:\Users\1\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
def merge_txt_files_to_dataset():
    all_data = []

    for filename in os.listdir(input_folder):
        if filename.endswith('.txt'):
            filepath = os.path.join(input_folder, filename)
            df = pd.read_csv(filepath, sep='\s+', header=None, names=columns)

            all_data.append(df)

    combined_df = pd.concat(all_data, ignore_index=True)
    combined_df.to_csv(output_file, index=False)
    print(f"Датасет сохранен в {output_file} (строк: {len(combined_df)})")

# Пример использования

merge_txt_files_to_dataset()
# Out:
# Датасет сохранен в K_Nu random.csv (строк: 100100)

# %%
df = pd.read_csv(output_file)
df = df[:50050]
df[:5]
# Out:
#        K_Nu  K_E  K_Rho  K_incl    F  K_lambda_r            A2    А2_surface  \
# 0  0.975432    1      1       1  0.1   10.000000  5.331349e-13  5.331373e-13
# 1  0.975432    1      1       1  0.2    5.000000  5.334835e-13  5.331484e-13
# 2  0.975432    1      1       1  0.3    3.333333  5.366578e-13  5.363075e-13
# 3  0.975432    1      1       1  0.4    2.500000  5.329255e-13  5.331888e-13
# 4  0.975432    1      1       1  0.5    2.000000  5.331508e-13  5.331765e-13
#
#    Nu_host medium             E   Rho           Vp           Vs            Z
# 0            0.25  5.000000e+10  2700  4687.745257  2728.366575  2502.294446
# 1            0.25  5.000000e+10  2700  4687.745257  2728.366575  2502.294446
# 2            0.25  5.000000e+10  2700  4687.745257  2728.366575  2502.294446
# 3            0.25  5.000000e+10  2700  4687.745257  2728.366575  2502.294446
# 4            0.25  5.000000e+10  2700  4687.745257  2728.366575  2502.294446

# %%
df['A2/A2_s'] = df['A2'] / df['А2_surface']
y = df[target_cols]
X = df[['A2/A2_s', 'F']]

# %%
scaler_X = StandardScaler()

X_scaled = scaler_X.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
model = Sequential([
    Dense(128, activation='relu', input_shape=(2,), name='hidden_layer_1'),
    Dropout(0.2),  # Добавляем Dropout для регуляризации
    Dense(64, activation='relu', name='hidden_layer_2'),
    Dropout(0.2),
    Dense(1, name='output_layer')
])
# Out:
# C:\Users\1\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='mse',
    metrics=['mae']
)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ hidden_layer_1 (Dense)          │ (None, 128)            │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden_layer_2 (Dense)          │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,705 (34.00 KB)
#  Trainable params: 8,705 (34.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Ранняя остановка для предотвращения переобучения
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True
)

# Обучение модели
history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 19s 11ms/step - loss: 0.0369 - mae: 0.1345 - val_loss: 0.0059 - val_mae: 0.0570
# Epoch 2/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - loss: 0.0125 - mae: 0.0880 - val_loss: 0.0048 - val_mae: 0.0509
# Epoch 3/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - loss: 0.0090 - mae: 0.0736 - val_loss: 0.0049 - val_mae: 0.0530
# Epoch 4/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0067 - mae: 0.0623 - val_loss: 0.0036 - val_mae: 0.0372
# Epoch 5/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 23s 13ms/step - loss: 0.0051 - mae: 0.0533 - val_loss: 0.0034 - val_mae: 0.0379
# Epoch 6/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - loss: 0.0042 - mae: 0.0467 - val_loss: 0.0031 - val_mae: 0.0344
# Epoch 7/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0038 - mae: 0.0433 - val_loss: 0.0031 - val_mae: 0.0362
# Epoch 8/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 19s 8ms/step - loss: 0.0035 - mae: 0.0414 - val_loss: 0.0028 - val_mae: 0.0326
# Epoch 9/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0034 - mae: 0.0404 - val_loss: 0.0030 - val_mae: 0.0334
# Epoch 10/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0033 - mae: 0.0393 - val_loss: 0.0029 - val_mae: 0.0335
# Epoch 11/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - loss: 0.0032 - mae: 0.0385 - val_loss: 0.0027 - val_mae: 0.0303
# Epoch 12/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0031 - mae: 0.0379 - val_loss: 0.0026 - val_mae: 0.0306
# Epoch 13/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0031 - mae: 0.0378 - val_loss: 0.0025 - val_mae: 0.0309
# Epoch 14/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0031 - mae: 0.0375 - val_loss: 0.0025 - val_mae: 0.0299
# Epoch 15/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0030 - mae: 0.0371 - val_loss: 0.0023 - val_mae: 0.0275
# Epoch 16/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0030 - mae: 0.0367 - val_loss: 0.0025 - val_mae: 0.0310
# Epoch 17/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0029 - mae: 0.0366 - val_loss: 0.0023 - val_mae: 0.0268
# Epoch 18/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0029 - mae: 0.0362 - val_loss: 0.0025 - val_mae: 0.0294
# Epoch 19/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0029 - mae: 0.0360 - val_loss: 0.0026 - val_mae: 0.0298
# Epoch 20/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0029 - mae: 0.0362 - val_loss: 0.0022 - val_mae: 0.0269
# Epoch 21/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0028 - mae: 0.0358 - val_loss: 0.0022 - val_mae: 0.0260
# Epoch 22/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0028 - mae: 0.0354 - val_loss: 0.0023 - val_mae: 0.0293
# Epoch 23/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0028 - mae: 0.0356 - val_loss: 0.0021 - val_mae: 0.0254
# Epoch 24/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0027 - mae: 0.0350 - val_loss: 0.0022 - val_mae: 0.0269
# Epoch 25/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0027 - mae: 0.0349 - val_loss: 0.0022 - val_mae: 0.0263
# Epoch 26/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0027 - mae: 0.0347 - val_loss: 0.0022 - val_mae: 0.0284
# Epoch 27/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0027 - mae: 0.0345 - val_loss: 0.0022 - val_mae: 0.0278
# Epoch 28/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0027 - mae: 0.0346 - val_loss: 0.0021 - val_mae: 0.0267
# Epoch 29/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - loss: 0.0027 - mae: 0.0348 - val_loss: 0.0023 - val_mae: 0.0284
# Epoch 30/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 13s 12ms/step - loss: 0.0027 - mae: 0.0347 - val_loss: 0.0021 - val_mae: 0.0272
# Epoch 31/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0026 - mae: 0.0341 - val_loss: 0.0021 - val_mae: 0.0272
# Epoch 32/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 0.0026 - mae: 0.0345 - val_loss: 0.0021 - val_mae: 0.0272
# Epoch 33/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0026 - mae: 0.0342 - val_loss: 0.0022 - val_mae: 0.0279
# Epoch 34/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0026 - mae: 0.0341 - val_loss: 0.0019 - val_mae: 0.0251
# Epoch 35/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0026 - mae: 0.0342 - val_loss: 0.0021 - val_mae: 0.0271
# Epoch 36/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0026 - mae: 0.0339 - val_loss: 0.0020 - val_mae: 0.0259
# Epoch 37/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0026 - mae: 0.0340 - val_loss: 0.0021 - val_mae: 0.0257
# Epoch 38/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0025 - mae: 0.0337 - val_loss: 0.0021 - val_mae: 0.0283
# Epoch 39/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0026 - mae: 0.0339 - val_loss: 0.0020 - val_mae: 0.0255
# Epoch 40/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0025 - mae: 0.0336 - val_loss: 0.0020 - val_mae: 0.0254
# Epoch 41/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0025 - mae: 0.0335 - val_loss: 0.0020 - val_mae: 0.0261
# Epoch 42/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - loss: 0.0025 - mae: 0.0335 - val_loss: 0.0020 - val_mae: 0.0254
# Epoch 43/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0025 - mae: 0.0334 - val_loss: 0.0019 - val_mae: 0.0260
# Epoch 44/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0025 - mae: 0.0333 - val_loss: 0.0019 - val_mae: 0.0246
# Epoch 45/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0025 - mae: 0.0333 - val_loss: 0.0019 - val_mae: 0.0254
# Epoch 46/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0025 - mae: 0.0331 - val_loss: 0.0019 - val_mae: 0.0242
# Epoch 47/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0025 - mae: 0.0333 - val_loss: 0.0018 - val_mae: 0.0239
# Epoch 48/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0025 - mae: 0.0330 - val_loss: 0.0020 - val_mae: 0.0267
# Epoch 49/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0025 - mae: 0.0330 - val_loss: 0.0019 - val_mae: 0.0253
# Epoch 50/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - loss: 0.0025 - mae: 0.0329 - val_loss: 0.0019 - val_mae: 0.0238
# Epoch 51/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0025 - mae: 0.0332 - val_loss: 0.0019 - val_mae: 0.0240
# Epoch 52/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0024 - mae: 0.0327 - val_loss: 0.0019 - val_mae: 0.0251
# Epoch 53/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0025 - mae: 0.0330 - val_loss: 0.0019 - val_mae: 0.0245
# Epoch 54/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0024 - mae: 0.0324 - val_loss: 0.0019 - val_mae: 0.0246
# Epoch 55/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0024 - mae: 0.0327 - val_loss: 0.0021 - val_mae: 0.0296
# Epoch 56/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0024 - mae: 0.0325 - val_loss: 0.0019 - val_mae: 0.0253
# Epoch 57/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 0.0024 - mae: 0.0325 - val_loss: 0.0019 - val_mae: 0.0256
# Epoch 58/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0024 - mae: 0.0325 - val_loss: 0.0019 - val_mae: 0.0267
# Epoch 59/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0024 - mae: 0.0326 - val_loss: 0.0019 - val_mae: 0.0253
# Epoch 60/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0024 - mae: 0.0326 - val_loss: 0.0020 - val_mae: 0.0263
# Epoch 61/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0024 - mae: 0.0325 - val_loss: 0.0020 - val_mae: 0.0281
# Epoch 62/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0024 - mae: 0.0323 - val_loss: 0.0019 - val_mae: 0.0264
# Epoch 63/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0024 - mae: 0.0322 - val_loss: 0.0018 - val_mae: 0.0230
# Epoch 64/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0024 - mae: 0.0323 - val_loss: 0.0018 - val_mae: 0.0251
# Epoch 65/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0024 - mae: 0.0325 - val_loss: 0.0020 - val_mae: 0.0256
# Epoch 66/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0024 - mae: 0.0323 - val_loss: 0.0019 - val_mae: 0.0243
# Epoch 67/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0024 - mae: 0.0324 - val_loss: 0.0018 - val_mae: 0.0254
# Epoch 68/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0024 - mae: 0.0324 - val_loss: 0.0019 - val_mae: 0.0258
# Epoch 69/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0024 - mae: 0.0325 - val_loss: 0.0018 - val_mae: 0.0232
# Epoch 70/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0024 - mae: 0.0324 - val_loss: 0.0019 - val_mae: 0.0256
# Epoch 71/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0024 - mae: 0.0321 - val_loss: 0.0019 - val_mae: 0.0258
# Epoch 72/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0023 - mae: 0.0318 - val_loss: 0.0019 - val_mae: 0.0255
# Epoch 73/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0024 - mae: 0.0322 - val_loss: 0.0018 - val_mae: 0.0248
# Epoch 74/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0024 - mae: 0.0321 - val_loss: 0.0018 - val_mae: 0.0248
# Epoch 75/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0024 - mae: 0.0321 - val_loss: 0.0019 - val_mae: 0.0263
# Epoch 76/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.0024 - mae: 0.0319 - val_loss: 0.0018 - val_mae: 0.0234
# Epoch 77/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.0024 - mae: 0.0320 - val_loss: 0.0018 - val_mae: 0.0243
# Epoch 78/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0024 - mae: 0.0322 - val_loss: 0.0018 - val_mae: 0.0245
# Epoch 79/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.0024 - mae: 0.0319 - val_loss: 0.0018 - val_mae: 0.0242
# Epoch 80/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0023 - mae: 0.0318 - val_loss: 0.0017 - val_mae: 0.0229
# Epoch 81/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0024 - mae: 0.0318 - val_loss: 0.0017 - val_mae: 0.0233
# Epoch 82/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0023 - mae: 0.0315 - val_loss: 0.0019 - val_mae: 0.0261
# Epoch 83/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0023 - mae: 0.0317 - val_loss: 0.0019 - val_mae: 0.0262
# Epoch 84/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0023 - mae: 0.0313 - val_loss: 0.0018 - val_mae: 0.0237
# Epoch 85/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0023 - mae: 0.0314 - val_loss: 0.0017 - val_mae: 0.0229
# Epoch 86/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0023 - mae: 0.0316 - val_loss: 0.0019 - val_mae: 0.0250
# Epoch 87/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0023 - mae: 0.0312 - val_loss: 0.0018 - val_mae: 0.0248
# Epoch 88/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0023 - mae: 0.0314 - val_loss: 0.0018 - val_mae: 0.0247
# Epoch 89/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0023 - mae: 0.0314 - val_loss: 0.0018 - val_mae: 0.0244
# Epoch 90/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0023 - mae: 0.0316 - val_loss: 0.0018 - val_mae: 0.0258
# Epoch 91/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0023 - mae: 0.0314 - val_loss: 0.0018 - val_mae: 0.0247
# Epoch 92/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0023 - mae: 0.0314 - val_loss: 0.0018 - val_mae: 0.0257
# Epoch 93/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0023 - mae: 0.0316 - val_loss: 0.0018 - val_mae: 0.0257
# Epoch 94/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0023 - mae: 0.0312 - val_loss: 0.0017 - val_mae: 0.0241
# Epoch 95/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0023 - mae: 0.0311 - val_loss: 0.0019 - val_mae: 0.0276
# Epoch 96/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0023 - mae: 0.0313 - val_loss: 0.0017 - val_mae: 0.0245
# Epoch 97/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0023 - mae: 0.0312 - val_loss: 0.0017 - val_mae: 0.0230
# Epoch 98/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0023 - mae: 0.0313 - val_loss: 0.0018 - val_mae: 0.0247
# Epoch 99/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0023 - mae: 0.0314 - val_loss: 0.0018 - val_mae: 0.0255
# Epoch 100/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0023 - mae: 0.0311 - val_loss: 0.0017 - val_mae: 0.0246

# %%
y_pred= np.array(model.predict(X_test)).flatten()
y_test = np.array(y_test)
y_test, y_pred
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# (array([0.886244, 1.10091 , 0.970412, ..., 0.940918, 1.07155 , 0.853664]),
#  array([0.878589  , 1.0998322 , 0.96366507, ..., 0.94687724, 1.0567939 ,
#         0.9876498 ], dtype=float32))

# %%
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
relative_errors = np.abs((y_test - y_pred) / y_test) * 100
mean_relative_error = np.mean(relative_errors)
std_relative_error = np.std(relative_errors)

# %%
print("\n" + "="*50)
print("РЕЗУЛЬТАТЫ МОДЕЛИ")
print("="*50)
print(f"Mean Squared Error (MSE): {mse:.6f}")
print(f"Mean Absolute Error (MAE): {mae:.6f}")
print(f"Mean Absolute Per Error (MAPE): {mape:.6f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.6f}")
print(f"R² Score: {r2:.6f}")
# Out:
# ==================================================
# РЕЗУЛЬТАТЫ МОДЕЛИ
# ==================================================
# Mean Squared Error (MSE): 0.001615
# Mean Absolute Error (MAE): 0.023602
# Mean Absolute Per Error (MAPE): 0.023935
# Root Mean Squared Error (RMSE): 0.040189
# R² Score: 0.874258

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# 1. График обучения
axes[0, 0].plot(history.history['loss'], label='Train Loss')
axes[0, 0].plot(history.history['val_loss'], label='Validation Loss')
axes[0, 0].set_title('График обучения (Loss)')
axes[0, 0].set_xlabel('Эпохи')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].legend()
axes[0, 0].grid(True)

# 2. Сравнение предсказанных и реальных значений
axes[0, 1].scatter(y_test, y_pred, alpha=0.5)
axes[0, 1].plot([y_test.min(), y_test.max()], 
                [y_test.min(), y_test.max()], 'r--', lw=2)
axes[0, 1].set_title('Предсказанные vs Реальные значения')
axes[0, 1].set_xlabel(f'Реальные значения {target_cols}')
axes[0, 1].set_ylabel(f'Предсказанные значения {target_cols}')
axes[0, 1].grid(True)

# 3. Распределение ошибок
errors = y_test.flatten() - y_pred.flatten()
axes[1, 0].hist(errors, bins=50, edgecolor='black', alpha=0.7)
axes[1, 0].set_title('Распределение ошибок предсказания')
axes[1, 0].set_xlabel('Ошибка')
axes[1, 0].set_ylabel('Частота')
axes[1, 0].grid(True)

#
# 4. Распределение относительных ошибок
axes[1, 1].hist(relative_errors, bins=50, edgecolor='black', alpha=0.7, color='green')
axes[1, 1].axvline(mean_relative_error, color='red', linestyle='--', 
                   label=f'Средняя: {mean_relative_error:.2f}%')
axes[1, 1].axvline(mean_relative_error + std_relative_error, color='orange', 
                   linestyle=':', label=f'±1σ: {std_relative_error:.2f}%')
axes[1, 1].axvline(mean_relative_error - std_relative_error, color='orange', linestyle=':')
axes[1, 1].set_title('Распределение относительных ошибок')
axes[1, 1].set_xlabel('Относительная ошибка (%)')
axes[1, 1].set_ylabel('Частота')
axes[1, 1].legend()
axes[1, 1].grid(True)

plt.tight_layout()
plt.show()

# Дополнительная статистика
print("\n" + "="*50)
print("ДЕТАЛЬНАЯ СТАТИСТИКА")
print("="*50)
print(f"Минимальная относительная ошибка: {relative_errors.min():.2f}%")
print(f"Максимальная относительная ошибка: {relative_errors.max():.2f}%")
print(f"Медианная относительная ошибка: {np.median(relative_errors):.2f}%")
print(f"25-й перцентиль: {np.percentile(relative_errors, 25):.2f}%")
print(f"75-й перцентиль: {np.percentile(relative_errors, 75):.2f}%")


# Примеры предсказаний
print("\n" + "="*50)
print("ПРИМЕРЫ ПРЕДСКАЗАНИЙ (первые 10 тестовых образцов)")
print("="*50)
examples = pd.DataFrame({
    f'Реальный {target_cols}': y_test.flatten()[:10],
    f'Предсказанный {target_cols}': y_pred.flatten()[:10],
    'Абсолютная ошибка': np.abs(y_test.flatten()[:10] - y_pred.flatten()[:10]),
    'Относительная ошибка (%)': relative_errors.flatten()[:10]
})
print(examples.to_string(index=False))

# Сохранение модели
model.save(f'{target_cols}_prediction_model.h5')
print("\nМодель сохранена")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ==================================================
# ДЕТАЛЬНАЯ СТАТИСТИКА
# ==================================================
# Минимальная относительная ошибка: 0.00%
# Максимальная относительная ошибка: 25.31%
# Медианная относительная ошибка: 1.17%
# 25-й перцентиль: 0.54%
# 75-й перцентиль: 2.67%
#
# ==================================================
# ПРИМЕРЫ ПРЕДСКАЗАНИЙ (первые 10 тестовых образцов)
# ==================================================
#  Реальный K_Nu  Предсказанный K_Nu  Абсолютная ошибка  Относительная ошибка (%)
#       0.886244            0.878589           0.007655                  0.863760
#       1.100910            1.099832           0.001078                  0.097903
#       0.970412            0.963665           0.006747                  0.695265
#       0.901454            1.006392           0.104938                 11.640971
#       0.898193            0.893837           0.004356                  0.484943
#       0.953049            0.906728           0.046321                  4.860305
#       0.833245            0.837667           0.004422                  0.530716
#       1.126340            1.104222           0.022118                  1.963732
#       1.134440            1.123858           0.010582                  0.932755
#       0.817469            0.825310           0.007841                  0.959230
#
# Модель сохранена

# %%
accuracy_5_percent = np.mean(relative_errors < 5) * 100
print(f"Процент предсказаний с ошибкой < 5%: {accuracy_5_percent:.2f}%")
# Out:
# Процент предсказаний с ошибкой < 5%: 87.42%
