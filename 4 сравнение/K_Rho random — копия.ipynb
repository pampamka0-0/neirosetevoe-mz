# %%
target_cols = 'K_Rho'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score,mean_absolute_percentage_error
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, callbacks
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import os

input_folder=f'C:/Users/1/projects/zadachi/2 задача/{target_cols} random'
output_file=f'{target_cols} random.csv'
columns = ['K_Nu', 'K_E', 'K_Rho', 'K_incl', 'F', 'K_lambda_r', 'A2', 'А2_surface',  'Nu_host medium', 'E', 'Rho', 'Vp', 'Vs', 'Z']
# Out:
# C:\Users\1\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
def merge_txt_files_to_dataset():
    all_data = []

    for filename in os.listdir(input_folder):
        if filename.endswith('.txt'):
            filepath = os.path.join(input_folder, filename)
            df = pd.read_csv(filepath, sep='\s+', header=None, names=columns)

            all_data.append(df)

    combined_df = pd.concat(all_data, ignore_index=True)
    combined_df.to_csv(output_file, index=False)
    print(f"Датасет сохранен в {output_file} (строк: {len(combined_df)})")

# Пример использования

merge_txt_files_to_dataset()
# Out:
# Датасет сохранен в K_Rho random.csv (строк: 100100)

# %%
df = pd.read_csv(output_file)
df = df[:20020]
df[:5]
# Out:
#    K_Nu  K_E    K_Rho  K_incl    F  K_lambda_r            A2    А2_surface  \
# 0     1    1  1.98177       1  0.1   10.000000  5.331373e-13  5.331413e-13
# 1     1    1  1.98177       1  0.2    5.000000  5.334628e-13  5.331372e-13
# 2     1    1  1.98177       1  0.3    3.333333  5.366540e-13  5.363021e-13
# 3     1    1  1.98177       1  0.4    2.500000  5.331394e-13  5.333450e-13
# 4     1    1  1.98177       1  0.5    2.000000  5.325957e-13  5.328923e-13
#
#    Nu_host medium             E   Rho           Vp           Vs            Z
# 0            0.25  5.000000e+10  2700  3348.629649  1933.332229  2502.294446
# 1            0.25  5.000000e+10  2700  3348.629649  1933.332229  2502.294446
# 2            0.25  5.000000e+10  2700  3348.629649  1933.332229  2502.294446
# 3            0.25  5.000000e+10  2700  3348.629649  1933.332229  2502.294446
# 4            0.25  5.000000e+10  2700  3348.629649  1933.332229  2502.294446

# %%
df['A2/A2_s'] = df['A2'] / df['А2_surface']
y = df[target_cols]
X = df[['A2/A2_s', 'F']]

# %%
scaler_X = StandardScaler()

X_scaled = scaler_X.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
model = Sequential([
    Dense(128, activation='relu', input_shape=(2,), name='hidden_layer_1'),
    Dropout(0.2),  # Добавляем Dropout для регуляризации
    Dense(64, activation='relu', name='hidden_layer_2'),
    Dropout(0.2),
    Dense(1, name='output_layer')
])
# Out:
# C:\Users\1\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='mse',
    metrics=['mae']
)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ hidden_layer_1 (Dense)          │ (None, 128)            │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden_layer_2 (Dense)          │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,705 (34.00 KB)
#  Trainable params: 8,705 (34.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Ранняя остановка для предотвращения переобучения
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True
)

# Обучение модели
history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 14s 13ms/step - loss: 0.2114 - mae: 0.3491 - val_loss: 0.0670 - val_mae: 0.1836
# Epoch 2/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - loss: 0.0966 - mae: 0.2390 - val_loss: 0.0575 - val_mae: 0.1646
# Epoch 3/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0850 - mae: 0.2207 - val_loss: 0.0547 - val_mae: 0.1548
# Epoch 4/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0788 - mae: 0.2103 - val_loss: 0.0525 - val_mae: 0.1468
# Epoch 5/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0745 - mae: 0.2017 - val_loss: 0.0500 - val_mae: 0.1428
# Epoch 6/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0697 - mae: 0.1938 - val_loss: 0.0481 - val_mae: 0.1412
# Epoch 7/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0681 - mae: 0.1902 - val_loss: 0.0481 - val_mae: 0.1396
# Epoch 8/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0671 - mae: 0.1877 - val_loss: 0.0468 - val_mae: 0.1329
# Epoch 9/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0640 - mae: 0.1822 - val_loss: 0.0490 - val_mae: 0.1410
# Epoch 10/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0629 - mae: 0.1793 - val_loss: 0.0449 - val_mae: 0.1266
# Epoch 11/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 0.0610 - mae: 0.1754 - val_loss: 0.0481 - val_mae: 0.1422
# Epoch 12/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0600 - mae: 0.1728 - val_loss: 0.0431 - val_mae: 0.1237
# Epoch 13/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0581 - mae: 0.1695 - val_loss: 0.0458 - val_mae: 0.1339
# Epoch 14/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0566 - mae: 0.1659 - val_loss: 0.0427 - val_mae: 0.1264
# Epoch 15/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0561 - mae: 0.1637 - val_loss: 0.0436 - val_mae: 0.1274
# Epoch 16/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0552 - mae: 0.1622 - val_loss: 0.0413 - val_mae: 0.1184
# Epoch 17/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0534 - mae: 0.1584 - val_loss: 0.0406 - val_mae: 0.1201
# Epoch 18/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0534 - mae: 0.1581 - val_loss: 0.0394 - val_mae: 0.1147
# Epoch 19/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0525 - mae: 0.1564 - val_loss: 0.0400 - val_mae: 0.1186
# Epoch 20/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0517 - mae: 0.1538 - val_loss: 0.0392 - val_mae: 0.1155
# Epoch 21/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.0501 - mae: 0.1513 - val_loss: 0.0409 - val_mae: 0.1242
# Epoch 22/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0506 - mae: 0.1517 - val_loss: 0.0394 - val_mae: 0.1198
# Epoch 23/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0496 - mae: 0.1500 - val_loss: 0.0401 - val_mae: 0.1175
# Epoch 24/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0488 - mae: 0.1484 - val_loss: 0.0404 - val_mae: 0.1165
# Epoch 25/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0485 - mae: 0.1466 - val_loss: 0.0381 - val_mae: 0.1079
# Epoch 26/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0481 - mae: 0.1467 - val_loss: 0.0373 - val_mae: 0.1118
# Epoch 27/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0474 - mae: 0.1444 - val_loss: 0.0368 - val_mae: 0.1116
# Epoch 28/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.0469 - mae: 0.1440 - val_loss: 0.0367 - val_mae: 0.1069
# Epoch 29/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0468 - mae: 0.1439 - val_loss: 0.0349 - val_mae: 0.1041
# Epoch 30/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0468 - mae: 0.1439 - val_loss: 0.0384 - val_mae: 0.1155
# Epoch 31/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0463 - mae: 0.1433 - val_loss: 0.0361 - val_mae: 0.1101
# Epoch 32/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0461 - mae: 0.1414 - val_loss: 0.0356 - val_mae: 0.1066
# Epoch 33/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0462 - mae: 0.1425 - val_loss: 0.0348 - val_mae: 0.1048
# Epoch 34/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0456 - mae: 0.1412 - val_loss: 0.0355 - val_mae: 0.1037
# Epoch 35/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 0.0453 - mae: 0.1397 - val_loss: 0.0345 - val_mae: 0.1036
# Epoch 36/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0449 - mae: 0.1389 - val_loss: 0.0347 - val_mae: 0.1063
# Epoch 37/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0440 - mae: 0.1376 - val_loss: 0.0330 - val_mae: 0.1046
# Epoch 38/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0436 - mae: 0.1367 - val_loss: 0.0334 - val_mae: 0.1024
# Epoch 39/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0438 - mae: 0.1373 - val_loss: 0.0341 - val_mae: 0.1075
# Epoch 40/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0430 - mae: 0.1355 - val_loss: 0.0320 - val_mae: 0.0999
# Epoch 41/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0431 - mae: 0.1352 - val_loss: 0.0319 - val_mae: 0.1006
# Epoch 42/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0427 - mae: 0.1354 - val_loss: 0.0328 - val_mae: 0.0988
# Epoch 43/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0425 - mae: 0.1341 - val_loss: 0.0326 - val_mae: 0.1034
# Epoch 44/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0425 - mae: 0.1344 - val_loss: 0.0344 - val_mae: 0.1099
# Epoch 45/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 0.0424 - mae: 0.1335 - val_loss: 0.0314 - val_mae: 0.0974
# Epoch 46/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - loss: 0.0421 - mae: 0.1335 - val_loss: 0.0321 - val_mae: 0.1026
# Epoch 47/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0418 - mae: 0.1336 - val_loss: 0.0308 - val_mae: 0.0997
# Epoch 48/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0420 - mae: 0.1335 - val_loss: 0.0314 - val_mae: 0.1024
# Epoch 49/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0413 - mae: 0.1321 - val_loss: 0.0326 - val_mae: 0.1069
# Epoch 50/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0419 - mae: 0.1328 - val_loss: 0.0316 - val_mae: 0.0987
# Epoch 51/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0413 - mae: 0.1313 - val_loss: 0.0324 - val_mae: 0.1019
# Epoch 52/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0415 - mae: 0.1322 - val_loss: 0.0292 - val_mae: 0.0893
# Epoch 53/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0417 - mae: 0.1324 - val_loss: 0.0309 - val_mae: 0.0954
# Epoch 54/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.0414 - mae: 0.1310 - val_loss: 0.0305 - val_mae: 0.0956
# Epoch 55/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0405 - mae: 0.1307 - val_loss: 0.0306 - val_mae: 0.1031
# Epoch 56/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0411 - mae: 0.1312 - val_loss: 0.0300 - val_mae: 0.0944
# Epoch 57/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0412 - mae: 0.1312 - val_loss: 0.0307 - val_mae: 0.0937
# Epoch 58/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0403 - mae: 0.1297 - val_loss: 0.0307 - val_mae: 0.0934
# Epoch 59/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0397 - mae: 0.1283 - val_loss: 0.0312 - val_mae: 0.1046
# Epoch 60/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0404 - mae: 0.1300 - val_loss: 0.0312 - val_mae: 0.1044
# Epoch 61/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 0.0401 - mae: 0.1298 - val_loss: 0.0306 - val_mae: 0.0917
# Epoch 62/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0404 - mae: 0.1295 - val_loss: 0.0304 - val_mae: 0.0918
# Epoch 63/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0406 - mae: 0.1297 - val_loss: 0.0297 - val_mae: 0.0947
# Epoch 64/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0406 - mae: 0.1294 - val_loss: 0.0293 - val_mae: 0.0921
# Epoch 65/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0402 - mae: 0.1289 - val_loss: 0.0302 - val_mae: 0.0947
# Epoch 66/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0399 - mae: 0.1283 - val_loss: 0.0294 - val_mae: 0.0925
# Epoch 67/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0400 - mae: 0.1291 - val_loss: 0.0319 - val_mae: 0.0927
# Epoch 68/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0393 - mae: 0.1272 - val_loss: 0.0298 - val_mae: 0.0911
# Epoch 69/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0404 - mae: 0.1289 - val_loss: 0.0296 - val_mae: 0.0914
# Epoch 70/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.0398 - mae: 0.1283 - val_loss: 0.0291 - val_mae: 0.0929
# Epoch 71/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0403 - mae: 0.1289 - val_loss: 0.0308 - val_mae: 0.0927
# Epoch 72/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.0390 - mae: 0.1268 - val_loss: 0.0311 - val_mae: 0.0963
# Epoch 73/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0393 - mae: 0.1263 - val_loss: 0.0312 - val_mae: 0.0988
# Epoch 74/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0401 - mae: 0.1280 - val_loss: 0.0293 - val_mae: 0.0917
# Epoch 75/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0396 - mae: 0.1272 - val_loss: 0.0313 - val_mae: 0.1029
# Epoch 76/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0399 - mae: 0.1279 - val_loss: 0.0294 - val_mae: 0.0908
# Epoch 77/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0396 - mae: 0.1270 - val_loss: 0.0302 - val_mae: 0.0880
# Epoch 78/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0395 - mae: 0.1270 - val_loss: 0.0287 - val_mae: 0.0898
# Epoch 79/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0392 - mae: 0.1263 - val_loss: 0.0296 - val_mae: 0.0919
# Epoch 80/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0397 - mae: 0.1269 - val_loss: 0.0297 - val_mae: 0.0942
# Epoch 81/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0387 - mae: 0.1260 - val_loss: 0.0289 - val_mae: 0.0887
# Epoch 82/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0387 - mae: 0.1245 - val_loss: 0.0287 - val_mae: 0.0890
# Epoch 83/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0393 - mae: 0.1268 - val_loss: 0.0299 - val_mae: 0.0908
# Epoch 84/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0392 - mae: 0.1263 - val_loss: 0.0302 - val_mae: 0.0961
# Epoch 85/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 0.0387 - mae: 0.1260 - val_loss: 0.0293 - val_mae: 0.0913
# Epoch 86/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0382 - mae: 0.1251 - val_loss: 0.0303 - val_mae: 0.0988
# Epoch 87/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.0392 - mae: 0.1264 - val_loss: 0.0294 - val_mae: 0.0936
# Epoch 88/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0385 - mae: 0.1253 - val_loss: 0.0284 - val_mae: 0.0906
# Epoch 89/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0383 - mae: 0.1251 - val_loss: 0.0283 - val_mae: 0.0889
# Epoch 90/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0387 - mae: 0.1252 - val_loss: 0.0294 - val_mae: 0.0925
# Epoch 91/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0394 - mae: 0.1273 - val_loss: 0.0286 - val_mae: 0.0894
# Epoch 92/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0389 - mae: 0.1257 - val_loss: 0.0285 - val_mae: 0.0875
# Epoch 93/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.0385 - mae: 0.1245 - val_loss: 0.0285 - val_mae: 0.0909
# Epoch 94/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0383 - mae: 0.1248 - val_loss: 0.0303 - val_mae: 0.1005
# Epoch 95/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0384 - mae: 0.1254 - val_loss: 0.0323 - val_mae: 0.1006
# Epoch 96/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0378 - mae: 0.1242 - val_loss: 0.0276 - val_mae: 0.0860
# Epoch 97/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0385 - mae: 0.1261 - val_loss: 0.0290 - val_mae: 0.0903
# Epoch 98/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0378 - mae: 0.1241 - val_loss: 0.0302 - val_mae: 0.0984
# Epoch 99/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 0.0378 - mae: 0.1242 - val_loss: 0.0289 - val_mae: 0.0886
# Epoch 100/100
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0378 - mae: 0.1230 - val_loss: 0.0298 - val_mae: 0.0939

# %%
y_pred= np.array(model.predict(X_test)).flatten()
y_test = np.array(y_test)
y_test, y_pred
# Out:
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# (array([1.33213 , 1.11693 , 1.60365 , ..., 0.967073, 0.731517, 0.781113]),
#  array([1.3630097 , 1.1368897 , 1.2701659 , ..., 0.9951773 , 0.72446173,
#         0.7786274 ], dtype=float32))

# %%
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
relative_errors = np.abs((y_test - y_pred) / y_test) * 100
mean_relative_error = np.mean(relative_errors)
std_relative_error = np.std(relative_errors)

# %%
print("\n" + "="*50)
print("РЕЗУЛЬТАТЫ МОДЕЛИ")
print("="*50)
print(f"Mean Squared Error (MSE): {mse:.6f}")
print(f"Mean Absolute Error (MAE): {mae:.6f}")
print(f"Mean Absolute Per Error (MAPE): {mape:.6f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.6f}")
print(f"R² Score: {r2:.6f}")
# Out:
# ==================================================
# РЕЗУЛЬТАТЫ МОДЕЛИ
# ==================================================
# Mean Squared Error (MSE): 0.030576
# Mean Absolute Error (MAE): 0.091064
# Mean Absolute Per Error (MAPE): 0.089227
# Root Mean Squared Error (RMSE): 0.174859
# R² Score: 0.839898

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# 1. График обучения
axes[0, 0].plot(history.history['loss'], label='Train Loss')
axes[0, 0].plot(history.history['val_loss'], label='Validation Loss')
axes[0, 0].set_title('График обучения (Loss)')
axes[0, 0].set_xlabel('Эпохи')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].legend()
axes[0, 0].grid(True)

# 2. Сравнение предсказанных и реальных значений
axes[0, 1].scatter(y_test, y_pred, alpha=0.5)
axes[0, 1].plot([y_test.min(), y_test.max()], 
                [y_test.min(), y_test.max()], 'r--', lw=2)
axes[0, 1].set_title('Предсказанные vs Реальные значения')
axes[0, 1].set_xlabel(f'Реальные значения {target_cols}')
axes[0, 1].set_ylabel(f'Предсказанные значения {target_cols}')
axes[0, 1].grid(True)

# 3. Распределение ошибок
errors = y_test.flatten() - y_pred.flatten()
axes[1, 0].hist(errors, bins=50, edgecolor='black', alpha=0.7)
axes[1, 0].set_title('Распределение ошибок предсказания')
axes[1, 0].set_xlabel('Ошибка')
axes[1, 0].set_ylabel('Частота')
axes[1, 0].grid(True)

#
# 4. Распределение относительных ошибок
axes[1, 1].hist(relative_errors, bins=50, edgecolor='black', alpha=0.7, color='green')
axes[1, 1].axvline(mean_relative_error, color='red', linestyle='--', 
                   label=f'Средняя: {mean_relative_error:.2f}%')
axes[1, 1].axvline(mean_relative_error + std_relative_error, color='orange', 
                   linestyle=':', label=f'±1σ: {std_relative_error:.2f}%')
axes[1, 1].axvline(mean_relative_error - std_relative_error, color='orange', linestyle=':')
axes[1, 1].set_title('Распределение относительных ошибок')
axes[1, 1].set_xlabel('Относительная ошибка (%)')
axes[1, 1].set_ylabel('Частота')
axes[1, 1].legend()
axes[1, 1].grid(True)

plt.tight_layout()
plt.show()

# Дополнительная статистика
print("\n" + "="*50)
print("ДЕТАЛЬНАЯ СТАТИСТИКА")
print("="*50)
print(f"Минимальная относительная ошибка: {relative_errors.min():.2f}%")
print(f"Максимальная относительная ошибка: {relative_errors.max():.2f}%")
print(f"Медианная относительная ошибка: {np.median(relative_errors):.2f}%")
print(f"25-й перцентиль: {np.percentile(relative_errors, 25):.2f}%")
print(f"75-й перцентиль: {np.percentile(relative_errors, 75):.2f}%")


# Примеры предсказаний
print("\n" + "="*50)
print("ПРИМЕРЫ ПРЕДСКАЗАНИЙ (первые 10 тестовых образцов)")
print("="*50)
examples = pd.DataFrame({
    f'Реальный {target_cols}': y_test.flatten()[:10],
    f'Предсказанный {target_cols}': y_pred.flatten()[:10],
    'Абсолютная ошибка': np.abs(y_test.flatten()[:10] - y_pred.flatten()[:10]),
    'Относительная ошибка (%)': relative_errors.flatten()[:10]
})
print(examples.to_string(index=False))

# Сохранение модели
model.save(f'{target_cols}_prediction_model.h5')
print("\nМодель сохранена")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ==================================================
# ДЕТАЛЬНАЯ СТАТИСТИКА
# ==================================================
# Минимальная относительная ошибка: 0.00%
# Максимальная относительная ошибка: 194.29%
# Медианная относительная ошибка: 2.28%
# 25-й перцентиль: 0.98%
# 75-й перцентиль: 7.18%
#
# ==================================================
# ПРИМЕРЫ ПРЕДСКАЗАНИЙ (первые 10 тестовых образцов)
# ==================================================
#  Реальный K_Rho  Предсказанный K_Rho  Абсолютная ошибка  Относительная ошибка (%)
#        1.332130             1.363010           0.030880                  2.318069
#        1.116930             1.136890           0.019960                  1.787014
#        1.603650             1.270166           0.333484                 20.795316
#        1.148140             1.155370           0.007230                  0.629704
#        1.550310             1.533626           0.016684                  1.076197
#        1.894600             1.882638           0.011962                  0.631387
#        1.275770             1.299892           0.024122                  1.890748
#        1.550310             1.607030           0.056720                  3.658633
#        1.583790             1.561510           0.022280                  1.406754
#        0.873634             0.876656           0.003022                  0.345918
#
# Модель сохранена

# %%
accuracy_5_percent = np.mean(relative_errors < 5) * 100
print(f"Процент предсказаний с ошибкой < 5%: {accuracy_5_percent:.2f}%")
# Out:
# Процент предсказаний с ошибкой < 5%: 68.88%
