# %%
target_cols = 'K_Rho'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score,mean_absolute_percentage_error
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, callbacks
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import os

input_folder=f'C:/Users/1/projects/zadachi/2 задача/{target_cols} random'
output_file=f'{target_cols} random.csv'
columns = ['K_Nu', 'K_E', 'K_Rho', 'K_incl', 'F', 'K_lambda_r', 'A2', 'А2_surface',  'Nu_host medium', 'E', 'Rho', 'Vp', 'Vs', 'Z']
# Out:
# C:\Users\1\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
def merge_txt_files_to_dataset():
    all_data = []

    for filename in os.listdir(input_folder):
        if filename.endswith('.txt'):
            filepath = os.path.join(input_folder, filename)
            df = pd.read_csv(filepath, sep='\s+', header=None, names=columns)

            all_data.append(df)

    combined_df = pd.concat(all_data, ignore_index=True)
    combined_df.to_csv(output_file, index=False)
    print(f"Датасет сохранен в {output_file} (строк: {len(combined_df)})")

# Пример использования

merge_txt_files_to_dataset()
# Out:
# Датасет сохранен в K_Rho random.csv (строк: 100100)

# %%
df = pd.read_csv(output_file)
df = df[:50050]
df[:5]
# Out:
#    K_Nu  K_E    K_Rho  K_incl    F  K_lambda_r            A2    А2_surface  \
# 0     1    1  1.98177       1  0.1   10.000000  5.331373e-13  5.331413e-13
# 1     1    1  1.98177       1  0.2    5.000000  5.334628e-13  5.331372e-13
# 2     1    1  1.98177       1  0.3    3.333333  5.366540e-13  5.363021e-13
# 3     1    1  1.98177       1  0.4    2.500000  5.331394e-13  5.333450e-13
# 4     1    1  1.98177       1  0.5    2.000000  5.325957e-13  5.328923e-13
#
#    Nu_host medium             E   Rho           Vp           Vs            Z
# 0            0.25  5.000000e+10  2700  3348.629649  1933.332229  2502.294446
# 1            0.25  5.000000e+10  2700  3348.629649  1933.332229  2502.294446
# 2            0.25  5.000000e+10  2700  3348.629649  1933.332229  2502.294446
# 3            0.25  5.000000e+10  2700  3348.629649  1933.332229  2502.294446
# 4            0.25  5.000000e+10  2700  3348.629649  1933.332229  2502.294446

# %%
df['A2/A2_s'] = df['A2'] / df['А2_surface']
y = df[target_cols]
X = df[['A2/A2_s', 'F']]

# %%
scaler_X = StandardScaler()

X_scaled = scaler_X.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
model = Sequential([
    Dense(128, activation='relu', input_shape=(2,), name='hidden_layer_1'),
    Dropout(0.2),  # Добавляем Dropout для регуляризации
    Dense(64, activation='relu', name='hidden_layer_2'),
    Dropout(0.2),
    Dense(1, name='output_layer')
])
# Out:
# C:\Users\1\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='mse',
    metrics=['mae']
)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ hidden_layer_1 (Dense)          │ (None, 128)            │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden_layer_2 (Dense)          │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,705 (34.00 KB)
#  Trainable params: 8,705 (34.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Ранняя остановка для предотвращения переобучения
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True
)

# Обучение модели
history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 30s 22ms/step - loss: 0.1260 - mae: 0.2681 - val_loss: 0.0637 - val_mae: 0.1864
# Epoch 2/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - loss: 0.0745 - mae: 0.2008 - val_loss: 0.0511 - val_mae: 0.1431
# Epoch 3/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - loss: 0.0665 - mae: 0.1846 - val_loss: 0.0472 - val_mae: 0.1397
# Epoch 4/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 13s 13ms/step - loss: 0.0613 - mae: 0.1738 - val_loss: 0.0493 - val_mae: 0.1503
# Epoch 5/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0575 - mae: 0.1658 - val_loss: 0.0427 - val_mae: 0.1321
# Epoch 6/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - loss: 0.0547 - mae: 0.1594 - val_loss: 0.0400 - val_mae: 0.1152
# Epoch 7/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0526 - mae: 0.1541 - val_loss: 0.0390 - val_mae: 0.1194
# Epoch 8/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0512 - mae: 0.1511 - val_loss: 0.0385 - val_mae: 0.1135
# Epoch 9/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0500 - mae: 0.1477 - val_loss: 0.0374 - val_mae: 0.1116
# Epoch 10/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0481 - mae: 0.1444 - val_loss: 0.0381 - val_mae: 0.1164
# Epoch 11/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0470 - mae: 0.1425 - val_loss: 0.0383 - val_mae: 0.1120
# Epoch 12/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - loss: 0.0468 - mae: 0.1421 - val_loss: 0.0367 - val_mae: 0.1086
# Epoch 13/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0461 - mae: 0.1401 - val_loss: 0.0349 - val_mae: 0.1021
# Epoch 14/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0448 - mae: 0.1384 - val_loss: 0.0357 - val_mae: 0.1125
# Epoch 15/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - loss: 0.0449 - mae: 0.1381 - val_loss: 0.0338 - val_mae: 0.0980
# Epoch 16/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0442 - mae: 0.1372 - val_loss: 0.0338 - val_mae: 0.1011
# Epoch 17/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0439 - mae: 0.1365 - val_loss: 0.0345 - val_mae: 0.0972
# Epoch 18/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0434 - mae: 0.1360 - val_loss: 0.0334 - val_mae: 0.0962
# Epoch 19/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0430 - mae: 0.1350 - val_loss: 0.0326 - val_mae: 0.0983
# Epoch 20/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0425 - mae: 0.1345 - val_loss: 0.0331 - val_mae: 0.1012
# Epoch 21/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0420 - mae: 0.1331 - val_loss: 0.0343 - val_mae: 0.1050
# Epoch 22/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - loss: 0.0420 - mae: 0.1331 - val_loss: 0.0338 - val_mae: 0.1024
# Epoch 23/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0416 - mae: 0.1330 - val_loss: 0.0331 - val_mae: 0.1008
# Epoch 24/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0413 - mae: 0.1327 - val_loss: 0.0329 - val_mae: 0.1024
# Epoch 25/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0408 - mae: 0.1316 - val_loss: 0.0320 - val_mae: 0.0977
# Epoch 26/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0409 - mae: 0.1316 - val_loss: 0.0309 - val_mae: 0.0981
# Epoch 27/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0402 - mae: 0.1309 - val_loss: 0.0301 - val_mae: 0.0939
# Epoch 28/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0402 - mae: 0.1310 - val_loss: 0.0302 - val_mae: 0.0966
# Epoch 29/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0400 - mae: 0.1296 - val_loss: 0.0301 - val_mae: 0.0986
# Epoch 30/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 13s 12ms/step - loss: 0.0390 - mae: 0.1282 - val_loss: 0.0289 - val_mae: 0.0913
# Epoch 31/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0394 - mae: 0.1293 - val_loss: 0.0283 - val_mae: 0.0858
# Epoch 32/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0390 - mae: 0.1283 - val_loss: 0.0309 - val_mae: 0.0932
# Epoch 33/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0385 - mae: 0.1276 - val_loss: 0.0292 - val_mae: 0.0981
# Epoch 34/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0389 - mae: 0.1278 - val_loss: 0.0300 - val_mae: 0.0959
# Epoch 35/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0388 - mae: 0.1281 - val_loss: 0.0313 - val_mae: 0.1009
# Epoch 36/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0388 - mae: 0.1274 - val_loss: 0.0295 - val_mae: 0.0895
# Epoch 37/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0381 - mae: 0.1263 - val_loss: 0.0282 - val_mae: 0.0894
# Epoch 38/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0384 - mae: 0.1266 - val_loss: 0.0289 - val_mae: 0.0919
# Epoch 39/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0384 - mae: 0.1269 - val_loss: 0.0296 - val_mae: 0.0940
# Epoch 40/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - loss: 0.0384 - mae: 0.1266 - val_loss: 0.0280 - val_mae: 0.0875
# Epoch 41/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0380 - mae: 0.1266 - val_loss: 0.0287 - val_mae: 0.0931
# Epoch 42/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0378 - mae: 0.1260 - val_loss: 0.0282 - val_mae: 0.0883
# Epoch 43/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0378 - mae: 0.1260 - val_loss: 0.0301 - val_mae: 0.0959
# Epoch 44/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0377 - mae: 0.1262 - val_loss: 0.0287 - val_mae: 0.0940
# Epoch 45/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0380 - mae: 0.1264 - val_loss: 0.0295 - val_mae: 0.0976
# Epoch 46/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0378 - mae: 0.1261 - val_loss: 0.0299 - val_mae: 0.0948
# Epoch 47/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0376 - mae: 0.1255 - val_loss: 0.0282 - val_mae: 0.0900
# Epoch 48/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - loss: 0.0374 - mae: 0.1250 - val_loss: 0.0295 - val_mae: 0.0960
# Epoch 49/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0376 - mae: 0.1251 - val_loss: 0.0282 - val_mae: 0.0916
# Epoch 50/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0371 - mae: 0.1252 - val_loss: 0.0278 - val_mae: 0.0911
# Epoch 51/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0381 - mae: 0.1255 - val_loss: 0.0284 - val_mae: 0.0905
# Epoch 52/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0372 - mae: 0.1248 - val_loss: 0.0297 - val_mae: 0.0947
# Epoch 53/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0374 - mae: 0.1251 - val_loss: 0.0287 - val_mae: 0.0899
# Epoch 54/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0372 - mae: 0.1246 - val_loss: 0.0278 - val_mae: 0.0910
# Epoch 55/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0375 - mae: 0.1248 - val_loss: 0.0274 - val_mae: 0.0866
# Epoch 56/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0371 - mae: 0.1241 - val_loss: 0.0289 - val_mae: 0.0909
# Epoch 57/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0375 - mae: 0.1249 - val_loss: 0.0276 - val_mae: 0.0877
# Epoch 58/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0376 - mae: 0.1247 - val_loss: 0.0278 - val_mae: 0.0910
# Epoch 59/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0369 - mae: 0.1241 - val_loss: 0.0272 - val_mae: 0.0868
# Epoch 60/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0372 - mae: 0.1241 - val_loss: 0.0275 - val_mae: 0.0884
# Epoch 61/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 0.0370 - mae: 0.1240 - val_loss: 0.0273 - val_mae: 0.0887
# Epoch 62/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0372 - mae: 0.1248 - val_loss: 0.0279 - val_mae: 0.0903
# Epoch 63/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0373 - mae: 0.1244 - val_loss: 0.0293 - val_mae: 0.0931
# Epoch 64/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0369 - mae: 0.1243 - val_loss: 0.0274 - val_mae: 0.0877
# Epoch 65/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0370 - mae: 0.1242 - val_loss: 0.0295 - val_mae: 0.0906
# Epoch 66/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0367 - mae: 0.1233 - val_loss: 0.0286 - val_mae: 0.0947
# Epoch 67/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0371 - mae: 0.1244 - val_loss: 0.0297 - val_mae: 0.0990
# Epoch 68/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0366 - mae: 0.1233 - val_loss: 0.0273 - val_mae: 0.0880
# Epoch 69/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 0.0368 - mae: 0.1230 - val_loss: 0.0291 - val_mae: 0.0984
# Epoch 70/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0373 - mae: 0.1240 - val_loss: 0.0294 - val_mae: 0.0931
# Epoch 71/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0372 - mae: 0.1243 - val_loss: 0.0292 - val_mae: 0.0975
# Epoch 72/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0371 - mae: 0.1237 - val_loss: 0.0276 - val_mae: 0.0864
# Epoch 73/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0368 - mae: 0.1234 - val_loss: 0.0283 - val_mae: 0.0968
# Epoch 74/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0367 - mae: 0.1234 - val_loss: 0.0282 - val_mae: 0.0881
# Epoch 75/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0368 - mae: 0.1234 - val_loss: 0.0296 - val_mae: 0.0910
# Epoch 76/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0369 - mae: 0.1234 - val_loss: 0.0283 - val_mae: 0.0908
# Epoch 77/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.0370 - mae: 0.1238 - val_loss: 0.0285 - val_mae: 0.0925
# Epoch 78/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0370 - mae: 0.1238 - val_loss: 0.0279 - val_mae: 0.0924
# Epoch 79/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0369 - mae: 0.1238 - val_loss: 0.0269 - val_mae: 0.0854
# Epoch 80/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0365 - mae: 0.1228 - val_loss: 0.0283 - val_mae: 0.0929
# Epoch 81/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0365 - mae: 0.1228 - val_loss: 0.0292 - val_mae: 0.0948
# Epoch 82/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0368 - mae: 0.1238 - val_loss: 0.0274 - val_mae: 0.0874
# Epoch 83/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0364 - mae: 0.1222 - val_loss: 0.0269 - val_mae: 0.0832
# Epoch 84/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0364 - mae: 0.1230 - val_loss: 0.0303 - val_mae: 0.0941
# Epoch 85/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0364 - mae: 0.1228 - val_loss: 0.0282 - val_mae: 0.0902
# Epoch 86/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0364 - mae: 0.1225 - val_loss: 0.0276 - val_mae: 0.0887
# Epoch 87/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0364 - mae: 0.1228 - val_loss: 0.0290 - val_mae: 0.0900
# Epoch 88/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0363 - mae: 0.1222 - val_loss: 0.0279 - val_mae: 0.0900
# Epoch 89/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0365 - mae: 0.1226 - val_loss: 0.0272 - val_mae: 0.0858
# Epoch 90/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0360 - mae: 0.1216 - val_loss: 0.0275 - val_mae: 0.0907
# Epoch 91/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0368 - mae: 0.1227 - val_loss: 0.0284 - val_mae: 0.0910
# Epoch 92/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.0360 - mae: 0.1220 - val_loss: 0.0275 - val_mae: 0.0890
# Epoch 93/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0366 - mae: 0.1225 - val_loss: 0.0268 - val_mae: 0.0819
# Epoch 94/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0361 - mae: 0.1214 - val_loss: 0.0272 - val_mae: 0.0860
# Epoch 95/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.0366 - mae: 0.1224 - val_loss: 0.0273 - val_mae: 0.0903
# Epoch 96/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.0360 - mae: 0.1212 - val_loss: 0.0272 - val_mae: 0.0889
# Epoch 97/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.0361 - mae: 0.1218 - val_loss: 0.0281 - val_mae: 0.0880
# Epoch 98/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0365 - mae: 0.1223 - val_loss: 0.0272 - val_mae: 0.0883
# Epoch 99/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0357 - mae: 0.1209 - val_loss: 0.0276 - val_mae: 0.0856
# Epoch 100/100
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0361 - mae: 0.1217 - val_loss: 0.0275 - val_mae: 0.0898

# %%
y_pred= np.array(model.predict(X_test)).flatten()
y_test = np.array(y_test)
y_test, y_pred
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# (array([1.50521 , 1.75151 , 1.66623 , ..., 1.33605 , 0.726824, 1.89858 ]),
#  array([1.2983928, 1.7502389, 1.6575254, ..., 1.3034127, 0.7316139,
#         1.1711291], dtype=float32))

# %%
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
relative_errors = np.abs((y_test - y_pred) / y_test) * 100
mean_relative_error = np.mean(relative_errors)
std_relative_error = np.std(relative_errors)

# %%
print("\n" + "="*50)
print("РЕЗУЛЬТАТЫ МОДЕЛИ")
print("="*50)
print(f"Mean Squared Error (MSE): {mse:.6f}")
print(f"Mean Absolute Error (MAE): {mae:.6f}")
print(f"Mean Absolute Per Error (MAPE): {mape:.6f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.6f}")
print(f"R² Score: {r2:.6f}")
# Out:
# ==================================================
# РЕЗУЛЬТАТЫ МОДЕЛИ
# ==================================================
# Mean Squared Error (MSE): 0.029120
# Mean Absolute Error (MAE): 0.085555
# Mean Absolute Per Error (MAPE): 0.081405
# Root Mean Squared Error (RMSE): 0.170646
# R² Score: 0.850085

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# 1. График обучения
axes[0, 0].plot(history.history['loss'], label='Train Loss')
axes[0, 0].plot(history.history['val_loss'], label='Validation Loss')
axes[0, 0].set_title('График обучения (Loss)')
axes[0, 0].set_xlabel('Эпохи')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].legend()
axes[0, 0].grid(True)

# 2. Сравнение предсказанных и реальных значений
axes[0, 1].scatter(y_test, y_pred, alpha=0.5)
axes[0, 1].plot([y_test.min(), y_test.max()], 
                [y_test.min(), y_test.max()], 'r--', lw=2)
axes[0, 1].set_title('Предсказанные vs Реальные значения')
axes[0, 1].set_xlabel(f'Реальные значения {target_cols}')
axes[0, 1].set_ylabel(f'Предсказанные значения {target_cols}')
axes[0, 1].grid(True)

# 3. Распределение ошибок
errors = y_test.flatten() - y_pred.flatten()
axes[1, 0].hist(errors, bins=50, edgecolor='black', alpha=0.7)
axes[1, 0].set_title('Распределение ошибок предсказания')
axes[1, 0].set_xlabel('Ошибка')
axes[1, 0].set_ylabel('Частота')
axes[1, 0].grid(True)

#
# 4. Распределение относительных ошибок
axes[1, 1].hist(relative_errors, bins=50, edgecolor='black', alpha=0.7, color='green')
axes[1, 1].axvline(mean_relative_error, color='red', linestyle='--', 
                   label=f'Средняя: {mean_relative_error:.2f}%')
axes[1, 1].axvline(mean_relative_error + std_relative_error, color='orange', 
                   linestyle=':', label=f'±1σ: {std_relative_error:.2f}%')
axes[1, 1].axvline(mean_relative_error - std_relative_error, color='orange', linestyle=':')
axes[1, 1].set_title('Распределение относительных ошибок')
axes[1, 1].set_xlabel('Относительная ошибка (%)')
axes[1, 1].set_ylabel('Частота')
axes[1, 1].legend()
axes[1, 1].grid(True)

plt.tight_layout()
plt.show()

# Дополнительная статистика
print("\n" + "="*50)
print("ДЕТАЛЬНАЯ СТАТИСТИКА")
print("="*50)
print(f"Минимальная относительная ошибка: {relative_errors.min():.2f}%")
print(f"Максимальная относительная ошибка: {relative_errors.max():.2f}%")
print(f"Медианная относительная ошибка: {np.median(relative_errors):.2f}%")
print(f"25-й перцентиль: {np.percentile(relative_errors, 25):.2f}%")
print(f"75-й перцентиль: {np.percentile(relative_errors, 75):.2f}%")


# Примеры предсказаний
print("\n" + "="*50)
print("ПРИМЕРЫ ПРЕДСКАЗАНИЙ (первые 10 тестовых образцов)")
print("="*50)
examples = pd.DataFrame({
    f'Реальный {target_cols}': y_test.flatten()[:10],
    f'Предсказанный {target_cols}': y_pred.flatten()[:10],
    'Абсолютная ошибка': np.abs(y_test.flatten()[:10] - y_pred.flatten()[:10]),
    'Относительная ошибка (%)': relative_errors.flatten()[:10]
})
print(examples.to_string(index=False))

# Сохранение модели
model.save(f'{target_cols}_prediction_model.h5')
print("\nМодель сохранена")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ==================================================
# ДЕТАЛЬНАЯ СТАТИСТИКА
# ==================================================
# Минимальная относительная ошибка: 0.00%
# Максимальная относительная ошибка: 173.10%
# Медианная относительная ошибка: 2.00%
# 25-й перцентиль: 0.79%
# 75-й перцентиль: 6.93%
#
# ==================================================
# ПРИМЕРЫ ПРЕДСКАЗАНИЙ (первые 10 тестовых образцов)
# ==================================================
#  Реальный K_Rho  Предсказанный K_Rho  Абсолютная ошибка  Относительная ошибка (%)
#        1.505210             1.298393           0.206817                 13.740091
#        1.751510             1.750239           0.001271                  0.072572
#        1.666230             1.657525           0.008705                  0.522412
#        1.023640             1.225297           0.201657                 19.700036
#        1.918410             1.872972           0.045438                  2.368523
#        1.147870             1.155031           0.007161                  0.623817
#        1.274230             1.243490           0.030740                  2.412420
#        1.145080             1.189558           0.044478                  3.884231
#        0.640246             0.676055           0.035809                  5.593083
#        1.333720             1.305101           0.028619                  2.145809
#
# Модель сохранена

# %%
accuracy_5_percent = np.mean(relative_errors < 5) * 100
print(f"Процент предсказаний с ошибкой < 5%: {accuracy_5_percent:.2f}%")
# Out:
# Процент предсказаний с ошибкой < 5%: 70.78%
