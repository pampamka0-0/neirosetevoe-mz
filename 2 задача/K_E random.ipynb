# %%
target_cols = 'K_E'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score,mean_absolute_percentage_error
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, callbacks
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import os

input_folder=f'C:/Users/1/projects/zadachi/2 задача/{target_cols} random'
output_file=f'{target_cols} random.csv'
columns = ['K_E',  'F', 'K_lambda_r', 'A2', 'А2_surface',  'Nu_host medium', 'E', 'Rho', 'Vp', 'Vs', 'Z']
# Out:
# C:\Users\1\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
def merge_txt_files_to_dataset():
    all_data = []

    for filename in os.listdir(input_folder):
        if filename.endswith('.txt'):
            filepath = os.path.join(input_folder, filename)
            df = pd.read_csv(filepath, sep='\s+', header=None, names=columns)

            all_data.append(df)

    combined_df = pd.concat(all_data, ignore_index=True)
    combined_df.to_csv(output_file, index=False)
    print(f"Датасет сохранен в {output_file} (строк: {len(combined_df)})")

# Пример использования

merge_txt_files_to_dataset()
# Out:
# Датасет сохранен в K_E random.csv (строк: 99900)

# %%
df = pd.read_csv(output_file)
df[:5]
# Out:
#        K_E    F  K_lambda_r            A2    А2_surface  Nu_host medium  \
# 0  1.09111  0.1   10.000000  5.331366e-13  5.331351e-13            0.25
# 1  1.09111  0.2    5.000000  5.333957e-13  5.331374e-13            0.25
# 2  1.09111  0.3    3.333333  5.365243e-13  5.366021e-13            0.25
# 3  1.09111  0.4    2.500000  5.361632e-13  5.350153e-13            0.25
# 4  1.09111  0.5    2.000000  5.431016e-13  5.376676e-13            0.25
#
#               E   Rho           Vp           Vs            Z
# 0  5.000000e+10  2700  4924.113005  2842.937969  2502.294446
# 1  5.000000e+10  2700  4924.113005  2842.937969  2502.294446
# 2  5.000000e+10  2700  4924.113005  2842.937969  2502.294446
# 3  5.000000e+10  2700  4924.113005  2842.937969  2502.294446
# 4  5.000000e+10  2700  4924.113005  2842.937969  2502.294446

# %%
df['A2/A2_s'] = df['A2'] / df['А2_surface']
y = df[target_cols]
X = df[['A2/A2_s', 'F']]

# %%
scaler_X = StandardScaler()

X_scaled = scaler_X.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
model = Sequential([
    Dense(128, activation='relu', input_shape=(2,), name='hidden_layer_1'),
    Dropout(0.2),  # Добавляем Dropout для регуляризации
    Dense(64, activation='relu', name='hidden_layer_2'),
    Dropout(0.2),
    Dense(1, name='output_layer')
])
# Out:
# C:\Users\1\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='mse',
    metrics=['mae']
)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ hidden_layer_1 (Dense)          │ (None, 128)            │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden_layer_2 (Dense)          │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,705 (34.00 KB)
#  Trainable params: 8,705 (34.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Ранняя остановка для предотвращения переобучения
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True
)

# Обучение модели
history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 20s 7ms/step - loss: 0.1181 - mae: 0.2551 - val_loss: 0.0412 - val_mae: 0.1286
# Epoch 2/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 0.0553 - mae: 0.1703 - val_loss: 0.0340 - val_mae: 0.1170
# Epoch 3/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - loss: 0.0429 - mae: 0.1451 - val_loss: 0.0278 - val_mae: 0.0949
# Epoch 4/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - loss: 0.0367 - mae: 0.1315 - val_loss: 0.0272 - val_mae: 0.0962
# Epoch 5/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0329 - mae: 0.1221 - val_loss: 0.0242 - val_mae: 0.0917
# Epoch 6/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0314 - mae: 0.1177 - val_loss: 0.0232 - val_mae: 0.0851
# Epoch 7/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.0299 - mae: 0.1137 - val_loss: 0.0233 - val_mae: 0.0788
# Epoch 8/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 19s 6ms/step - loss: 0.0289 - mae: 0.1111 - val_loss: 0.0219 - val_mae: 0.0775
# Epoch 9/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - loss: 0.0288 - mae: 0.1101 - val_loss: 0.0239 - val_mae: 0.0858
# Epoch 10/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.0281 - mae: 0.1084 - val_loss: 0.0211 - val_mae: 0.0787
# Epoch 11/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0275 - mae: 0.1069 - val_loss: 0.0197 - val_mae: 0.0691
# Epoch 12/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - loss: 0.0272 - mae: 0.1061 - val_loss: 0.0207 - val_mae: 0.0740
# Epoch 13/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 19s 6ms/step - loss: 0.0269 - mae: 0.1051 - val_loss: 0.0212 - val_mae: 0.0726
# Epoch 14/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - loss: 0.0269 - mae: 0.1052 - val_loss: 0.0244 - val_mae: 0.0898
# Epoch 15/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.0266 - mae: 0.1043 - val_loss: 0.0211 - val_mae: 0.0784
# Epoch 16/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.0264 - mae: 0.1036 - val_loss: 0.0197 - val_mae: 0.0699
# Epoch 17/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - loss: 0.0259 - mae: 0.1024 - val_loss: 0.0202 - val_mae: 0.0709
# Epoch 18/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0258 - mae: 0.1019 - val_loss: 0.0195 - val_mae: 0.0749
# Epoch 19/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0256 - mae: 0.1015 - val_loss: 0.0198 - val_mae: 0.0721
# Epoch 20/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0259 - mae: 0.1022 - val_loss: 0.0222 - val_mae: 0.0812
# Epoch 21/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0254 - mae: 0.1008 - val_loss: 0.0185 - val_mae: 0.0670
# Epoch 22/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 22s 7ms/step - loss: 0.0252 - mae: 0.1004 - val_loss: 0.0203 - val_mae: 0.0757
# Epoch 23/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0253 - mae: 0.1006 - val_loss: 0.0185 - val_mae: 0.0660
# Epoch 24/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - loss: 0.0249 - mae: 0.0997 - val_loss: 0.0190 - val_mae: 0.0696
# Epoch 25/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 19s 6ms/step - loss: 0.0250 - mae: 0.0999 - val_loss: 0.0185 - val_mae: 0.0675
# Epoch 26/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0250 - mae: 0.0996 - val_loss: 0.0194 - val_mae: 0.0703
# Epoch 27/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0249 - mae: 0.0994 - val_loss: 0.0191 - val_mae: 0.0676
# Epoch 28/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.0247 - mae: 0.0991 - val_loss: 0.0210 - val_mae: 0.0774
# Epoch 29/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0249 - mae: 0.0993 - val_loss: 0.0183 - val_mae: 0.0680
# Epoch 30/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - loss: 0.0248 - mae: 0.0990 - val_loss: 0.0181 - val_mae: 0.0658
# Epoch 31/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0246 - mae: 0.0986 - val_loss: 0.0189 - val_mae: 0.0670
# Epoch 32/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 24s 7ms/step - loss: 0.0247 - mae: 0.0989 - val_loss: 0.0217 - val_mae: 0.0728
# Epoch 33/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.0246 - mae: 0.0986 - val_loss: 0.0199 - val_mae: 0.0712
# Epoch 34/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.0245 - mae: 0.0984 - val_loss: 0.0182 - val_mae: 0.0626
# Epoch 35/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.0244 - mae: 0.0979 - val_loss: 0.0192 - val_mae: 0.0736
# Epoch 36/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0244 - mae: 0.0985 - val_loss: 0.0178 - val_mae: 0.0657
# Epoch 37/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 16s 4ms/step - loss: 0.0244 - mae: 0.0981 - val_loss: 0.0191 - val_mae: 0.0657
# Epoch 38/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.0243 - mae: 0.0979 - val_loss: 0.0194 - val_mae: 0.0739
# Epoch 39/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.0242 - mae: 0.0975 - val_loss: 0.0202 - val_mae: 0.0736
# Epoch 40/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0243 - mae: 0.0977 - val_loss: 0.0181 - val_mae: 0.0665
# Epoch 41/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0241 - mae: 0.0975 - val_loss: 0.0204 - val_mae: 0.0709
# Epoch 42/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0240 - mae: 0.0972 - val_loss: 0.0196 - val_mae: 0.0677
# Epoch 43/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0240 - mae: 0.0969 - val_loss: 0.0196 - val_mae: 0.0680
# Epoch 44/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.0242 - mae: 0.0970 - val_loss: 0.0174 - val_mae: 0.0630
# Epoch 45/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - loss: 0.0237 - mae: 0.0965 - val_loss: 0.0174 - val_mae: 0.0618
# Epoch 46/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - loss: 0.0237 - mae: 0.0965 - val_loss: 0.0187 - val_mae: 0.0647
# Epoch 47/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0238 - mae: 0.0963 - val_loss: 0.0188 - val_mae: 0.0710
# Epoch 48/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0235 - mae: 0.0958 - val_loss: 0.0195 - val_mae: 0.0690
# Epoch 49/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - loss: 0.0238 - mae: 0.0962 - val_loss: 0.0178 - val_mae: 0.0640
# Epoch 50/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0237 - mae: 0.0961 - val_loss: 0.0197 - val_mae: 0.0699
# Epoch 51/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0237 - mae: 0.0960 - val_loss: 0.0183 - val_mae: 0.0697
# Epoch 52/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0236 - mae: 0.0960 - val_loss: 0.0179 - val_mae: 0.0611
# Epoch 53/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0235 - mae: 0.0956 - val_loss: 0.0185 - val_mae: 0.0648
# Epoch 54/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0235 - mae: 0.0960 - val_loss: 0.0185 - val_mae: 0.0652
# Epoch 55/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.0235 - mae: 0.0957 - val_loss: 0.0175 - val_mae: 0.0648
# Epoch 56/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0233 - mae: 0.0953 - val_loss: 0.0184 - val_mae: 0.0664
# Epoch 57/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0234 - mae: 0.0953 - val_loss: 0.0190 - val_mae: 0.0685
# Epoch 58/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0233 - mae: 0.0954 - val_loss: 0.0191 - val_mae: 0.0723
# Epoch 59/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.0235 - mae: 0.0957 - val_loss: 0.0198 - val_mae: 0.0693
# Epoch 60/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0236 - mae: 0.0959 - val_loss: 0.0175 - val_mae: 0.0638
# Epoch 61/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - loss: 0.0234 - mae: 0.0953 - val_loss: 0.0188 - val_mae: 0.0727
# Epoch 62/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0231 - mae: 0.0946 - val_loss: 0.0182 - val_mae: 0.0617
# Epoch 63/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - loss: 0.0236 - mae: 0.0956 - val_loss: 0.0173 - val_mae: 0.0624
# Epoch 64/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0232 - mae: 0.0948 - val_loss: 0.0187 - val_mae: 0.0694
# Epoch 65/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - loss: 0.0234 - mae: 0.0954 - val_loss: 0.0174 - val_mae: 0.0685
# Epoch 66/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0230 - mae: 0.0944 - val_loss: 0.0172 - val_mae: 0.0634
# Epoch 67/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0232 - mae: 0.0944 - val_loss: 0.0202 - val_mae: 0.0728
# Epoch 68/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - loss: 0.0233 - mae: 0.0952 - val_loss: 0.0181 - val_mae: 0.0640
# Epoch 69/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - loss: 0.0231 - mae: 0.0945 - val_loss: 0.0190 - val_mae: 0.0713
# Epoch 70/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0230 - mae: 0.0946 - val_loss: 0.0181 - val_mae: 0.0684
# Epoch 71/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - loss: 0.0229 - mae: 0.0940 - val_loss: 0.0174 - val_mae: 0.0626
# Epoch 72/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0229 - mae: 0.0939 - val_loss: 0.0182 - val_mae: 0.0660
# Epoch 73/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0230 - mae: 0.0944 - val_loss: 0.0181 - val_mae: 0.0616
# Epoch 74/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0229 - mae: 0.0940 - val_loss: 0.0174 - val_mae: 0.0674
# Epoch 75/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0231 - mae: 0.0945 - val_loss: 0.0182 - val_mae: 0.0663
# Epoch 76/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0229 - mae: 0.0941 - val_loss: 0.0174 - val_mae: 0.0612
# Epoch 77/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0229 - mae: 0.0936 - val_loss: 0.0177 - val_mae: 0.0637
# Epoch 78/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0226 - mae: 0.0935 - val_loss: 0.0177 - val_mae: 0.0625
# Epoch 79/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0229 - mae: 0.0938 - val_loss: 0.0179 - val_mae: 0.0679
# Epoch 80/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0230 - mae: 0.0941 - val_loss: 0.0178 - val_mae: 0.0651
# Epoch 81/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0227 - mae: 0.0935 - val_loss: 0.0184 - val_mae: 0.0650
# Epoch 82/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0231 - mae: 0.0945 - val_loss: 0.0165 - val_mae: 0.0623
# Epoch 83/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0230 - mae: 0.0937 - val_loss: 0.0172 - val_mae: 0.0684
# Epoch 84/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0228 - mae: 0.0936 - val_loss: 0.0179 - val_mae: 0.0664
# Epoch 85/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0227 - mae: 0.0935 - val_loss: 0.0169 - val_mae: 0.0614
# Epoch 86/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0227 - mae: 0.0935 - val_loss: 0.0168 - val_mae: 0.0606
# Epoch 87/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - loss: 0.0227 - mae: 0.0937 - val_loss: 0.0177 - val_mae: 0.0621
# Epoch 88/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0224 - mae: 0.0927 - val_loss: 0.0173 - val_mae: 0.0599
# Epoch 89/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0226 - mae: 0.0931 - val_loss: 0.0166 - val_mae: 0.0607
# Epoch 90/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0223 - mae: 0.0928 - val_loss: 0.0179 - val_mae: 0.0685
# Epoch 91/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 0.0227 - mae: 0.0936 - val_loss: 0.0166 - val_mae: 0.0607
# Epoch 92/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.0225 - mae: 0.0935 - val_loss: 0.0174 - val_mae: 0.0652
# Epoch 93/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0226 - mae: 0.0929 - val_loss: 0.0179 - val_mae: 0.0645
# Epoch 94/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0229 - mae: 0.0936 - val_loss: 0.0171 - val_mae: 0.0593
# Epoch 95/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0224 - mae: 0.0927 - val_loss: 0.0171 - val_mae: 0.0628
# Epoch 96/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0227 - mae: 0.0933 - val_loss: 0.0165 - val_mae: 0.0590
# Epoch 97/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.0223 - mae: 0.0926 - val_loss: 0.0166 - val_mae: 0.0581
# Epoch 98/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0224 - mae: 0.0928 - val_loss: 0.0168 - val_mae: 0.0647
# Epoch 99/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0226 - mae: 0.0932 - val_loss: 0.0176 - val_mae: 0.0635
# Epoch 100/100
# 1998/1998 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0225 - mae: 0.0927 - val_loss: 0.0171 - val_mae: 0.0600

# %%
y_pred= np.array(model.predict(X_test)).flatten()
y_test = np.array(y_test)
y_test, y_pred
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# (array([1.41706 , 1.9705  , 1.54119 , ..., 0.803812, 0.677577, 1.51436 ]),
#  array([1.4340147, 1.9374092, 1.5253031, ..., 0.8202846, 0.6944526,
#         1.5052309], dtype=float32))

# %%
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
relative_errors = np.abs((y_test - y_pred) / y_test) * 100
mean_relative_error = np.mean(relative_errors)
std_relative_error = np.std(relative_errors)

# %%
print("\n" + "="*50)
print("РЕЗУЛЬТАТЫ МОДЕЛИ")
print("="*50)
print(f"Mean Squared Error (MSE): {mse:.6f}")
print(f"Mean Absolute Error (MAE): {mae:.6f}")
print(f"Mean Absolute Per Error (MAPE): {mape:.6f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.6f}")
print(f"R² Score: {r2:.6f}")
# Out:
# ==================================================
# РЕЗУЛЬТАТЫ МОДЕЛИ
# ==================================================
# Mean Squared Error (MSE): 0.015435
# Mean Absolute Error (MAE): 0.057813
# Mean Absolute Per Error (MAPE): 0.055709
# Root Mean Squared Error (RMSE): 0.124240
# R² Score: 0.913723

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# 1. График обучения
axes[0, 0].plot(history.history['loss'], label='Train Loss')
axes[0, 0].plot(history.history['val_loss'], label='Validation Loss')
axes[0, 0].set_title('График обучения (Loss)')
axes[0, 0].set_xlabel('Эпохи')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].legend()
axes[0, 0].grid(True)

# 2. Сравнение предсказанных и реальных значений
axes[0, 1].scatter(y_test, y_pred, alpha=0.5)
axes[0, 1].plot([y_test.min(), y_test.max()], 
                [y_test.min(), y_test.max()], 'r--', lw=2)
axes[0, 1].set_title('Предсказанные vs Реальные значения')
axes[0, 1].set_xlabel(f'Реальные значения {target_cols}')
axes[0, 1].set_ylabel(f'Предсказанные значения {target_cols}')
axes[0, 1].grid(True)

# 3. Распределение ошибок
errors = y_test.flatten() - y_pred.flatten()
axes[1, 0].hist(errors, bins=50, edgecolor='black', alpha=0.7)
axes[1, 0].set_title('Распределение ошибок предсказания')
axes[1, 0].set_xlabel('Ошибка')
axes[1, 0].set_ylabel('Частота')
axes[1, 0].grid(True)

#
# 4. Распределение относительных ошибок
axes[1, 1].hist(relative_errors, bins=50, edgecolor='black', alpha=0.7, color='green')
axes[1, 1].axvline(mean_relative_error, color='red', linestyle='--', 
                   label=f'Средняя: {mean_relative_error:.2f}%')
axes[1, 1].axvline(mean_relative_error + std_relative_error, color='orange', 
                   linestyle=':', label=f'±1σ: {std_relative_error:.2f}%')
axes[1, 1].axvline(mean_relative_error - std_relative_error, color='orange', linestyle=':')
axes[1, 1].set_title('Распределение относительных ошибок')
axes[1, 1].set_xlabel('Относительная ошибка (%)')
axes[1, 1].set_ylabel('Частота')
axes[1, 1].legend()
axes[1, 1].grid(True)

plt.tight_layout()
plt.show()

# Дополнительная статистика
print("\n" + "="*50)
print("ДЕТАЛЬНАЯ СТАТИСТИКА")
print("="*50)
print(f"Минимальная относительная ошибка: {relative_errors.min():.2f}%")
print(f"Максимальная относительная ошибка: {relative_errors.max():.2f}%")
print(f"Медианная относительная ошибка: {np.median(relative_errors):.2f}%")
print(f"25-й перцентиль: {np.percentile(relative_errors, 25):.2f}%")
print(f"75-й перцентиль: {np.percentile(relative_errors, 75):.2f}%")


# Примеры предсказаний
print("\n" + "="*50)
print("ПРИМЕРЫ ПРЕДСКАЗАНИЙ (первые 10 тестовых образцов)")
print("="*50)
examples = pd.DataFrame({
    f'Реальный {target_cols}': y_test.flatten()[:10],
    f'Предсказанный {target_cols}': y_pred.flatten()[:10],
    'Абсолютная ошибка': np.abs(y_test.flatten()[:10] - y_pred.flatten()[:10]),
    'Относительная ошибка (%)': relative_errors.flatten()[:10]
})
print(examples.to_string(index=False))

# Сохранение модели
model.save(f'{target_cols}_prediction_model.h5')
print("\nМодель сохранена")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ==================================================
# ДЕТАЛЬНАЯ СТАТИСТИКА
# ==================================================
# Минимальная относительная ошибка: 0.00%
# Максимальная относительная ошибка: 201.78%
# Медианная относительная ошибка: 1.92%
# 25-й перцентиль: 0.84%
# 75-й перцентиль: 4.31%
#
# ==================================================
# ПРИМЕРЫ ПРЕДСКАЗАНИЙ (первые 10 тестовых образцов)
# ==================================================
#  Реальный K_E  Предсказанный K_E  Абсолютная ошибка  Относительная ошибка (%)
#      1.417060           1.434015           0.016955                  1.196469
#      1.970500           1.937409           0.033091                  1.679312
#      1.541190           1.525303           0.015887                  1.030819
#      0.539542           0.499472           0.040070                  7.426709
#      0.760235           0.764614           0.004379                  0.576051
#      1.765380           1.731973           0.033407                  1.892358
#      1.191750           1.197868           0.006118                  0.513342
#      1.599120           1.685968           0.086848                  5.430982
#      0.642649           0.623307           0.019342                  3.009676
#      1.269720           1.253320           0.016400                  1.291597
#
# Модель сохранена

# %%
accuracy_5_percent = np.mean(relative_errors < 5) * 100
print(f"Процент предсказаний с ошибкой < 5%: {accuracy_5_percent:.2f}%")
# Out:
# Процент предсказаний с ошибкой < 5%: 78.42%
